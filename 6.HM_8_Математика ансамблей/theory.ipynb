# %% [markdown]
# **Ансамбль моделей** — это метод, в котором несколько алгоритмов (или вариации одного и того же) обучаются на одних данных, а итоговый прогноз строится на основе всех полученных от моделей прогнозов.

# %% [markdown]
# # <center>Бутстреппинг. Бэггинг</center>

# %% [markdown]
# В основе бэггинга лежит статистический метод, который называется **бутстрепом (bootstrap)**. Идея бутстрепа заключается в генерации выборок размера n из исходного датасета размера N путём случайного выбора элементов с повторениями в каждом из наблюдений.
#
# ![image.png](https://lms.skillfactory.ru/asset-v1:SkillFactory+DST-3.0+28FEB2021+type@asset+block@MATHML_md9_2_1.png)

# %%
# Задание 2.2

import numpy as np

a = np.array([4.4, 3.8, 4.8, 4.0, 3.4, 4.2, 5.2])
b = a.mean()
round(np.sum((a - b)**2)/7, 3)
# Out:
# 0.317

# %% [markdown]
# ## <center>Bias и Variance</center>

# %% [markdown]
# **Смещение** — это разница между математическим ожиданием для прогноза и реальным значением:
#
# $$Bias[\hat{f}(x)] = E[\hat{f}(x)]-y$$
#
# > Смысл смещения — способность получить лучшую среди всех возможных моделей, то есть максимально точные прогнозы.
#
# **Алгоритмы со стабильно маленьким смещением:**
#
# * KNN (n=1)
# * метод опорных векторов
# * деревья решений с большой глубиной
#
# **Алгоритмы с большим смещением:**
#
# * линейная регрессия
# * логистическая регрессия
# * деревья решений с маленькой глубиной

# %% [markdown]
# **Разброс** — это величина разницы в результатах обучения модели на разных выборках:
#
# $$\operatorname{Var}[\hat{f}(x)]=\mathrm{E}\left[\left(\mathrm{E}[\hat{f}(x)]-\hat{f}(x)\right)^{2}\right]$$
#
# Разброс характеризует устойчивость модели к изменениям в обучающей выборке:
#
# * Если результат сильно зависит от того, какие объекты присутствуют в выборке, разброс будет большим.
#
# * Если алгоритм работает стабильно вне зависимости от особенностей выборки, разброс будет маленьким.
#
# **Алгоритмы, споказывающие маленький разброс:**
#
# * линейная регрессия
# * логистическая регрессия
# * деревья решений с маленькой глубиной
#
# **Алгоритмы, споказывающие большой разброс:**
#
# * деревья решений с большой глубиной
# * KNN
# * метод опорных векторов

# %% [markdown]
# > Наша ошибка — это сумма квадрата смещения, разброса и неустранимой случайной ошибки. Теперь мы понимаем, из чего состоит ошибка модели. Такое представление помогает нам исследовать с теоретической точки зрения некоторые алгоритмы машинного обучения и часто используется при изучении ансамблей.

# %% [markdown]
# ## <center>Бэггинг</center>

# %% [markdown]
# Его идея состоит в том, что мы берём несколько независимых моделей и усредняем полученные по ним результаты. Таким образом мы получаем модель, имеющую меньший разброс, так как при её построении мы учли несколько моделей.
#
# Как уже было сказано, в реальности получить много независимых выборок слишком сложно, так как найти столько данных обычно невозможно. Поэтому мы используем бутстреп-выборки.
#
# > Важно отметить, что при бэггинге размер каждой бутстреп-выборки должен совпадать с размером исходной выборки.

# %% [markdown]
# * Если мы рассматриваем задачу классификации, то, по сути, модели «голосуют» за свой класс.
# * Если мы рассматриваем задачу регрессии, то результат — просто среднее арифметическое прогнозов по всем моделям.

# %% [markdown]
# **Резюмируем**:
#
# * Бэггинг даёт уменьшение ошибки в  раз по сравнению с одиночной моделью.
# * Бэггинг не уменьшает смещение по сравнению с одиночной моделью.
# * Бэггинг уменьшает разброс в  раз по сравнению с одиночной моделью.

# %% [markdown]
# > Важно отметить, что эти утверждения выведены и доказаны теоретически и будут выполняться на практике только в том случае, если между ошибками нулевая корреляция.

# %%
# Задание 2.7

import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/wineQualityReds.csv')
df.head()
# Out:
#    Unnamed: 0  fixed.acidity  volatile.acidity  citric.acid  residual.sugar  \
# 0           1            7.4              0.70         0.00             1.9
# 1           2            7.8              0.88         0.00             2.6
# 2           3            7.8              0.76         0.04             2.3
# 3           4           11.2              0.28         0.56             1.9
# 4           5            7.4              0.70         0.00             1.9
#
#    chlorides  free.sulfur.dioxide  total.sulfur.dioxide  density    pH  \
# 0      0.076                 11.0                  34.0   0.9978  3.51
# 1      0.098                 25.0                  67.0   0.9968  3.20
# 2      0.092                 15.0                  54.0   0.9970  3.26
# 3      0.075                 17.0                  60.0   0.9980  3.16
# 4      0.076                 11.0                  34.0   0.9978  3.51
#
#    sulphates  alcohol  quality
# 0       0.56      9.4        5
# 1       0.68      9.8        5
# 2       0.65      9.8        5
# 3       0.58      9.8        6
# 4       0.56      9.4        5

# %%
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import f1_score

# %%
df['target'] = np.where(df.quality >=6,1,0)

y= df['target']
X = df.drop(['target', 'quality'], axis= 1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
preds_train = model.predict(X_train)
preds_test = model.predict(X_test)
f1_score(preds_test, y_test)
# Out:
# c:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7390476190476191

# %%
model = DecisionTreeClassifier(max_depth = 10, random_state=42)
model.fit(X_train, y_train)
preds_train = model.predict(X_train)
preds_test = model.predict(X_test)
f1_score(preds_test, y_test)
# Out:
# 0.7601476014760148

# %%
# Задание 2.8

from sklearn.ensemble import BaggingClassifier

model = BaggingClassifier(estimator=DecisionTreeClassifier(max_depth = 10, random_state=42), n_estimators=1500, random_state=42).fit(X_train, y_train)
preds_train = model.predict(X_train)
preds_test = model.predict(X_test)
f1_score(preds_test, y_test)
# Out:
# 0.8239700374531835

# %% [markdown]
# ## <center>Случайный лес</center>

# %% [markdown]
# ![image.pmg](https://lms-cdn.skillfactory.ru/assets/courseware/v1/5447a7937de6636597fac98b4f0a9f62/asset-v1:Skillfactory+DSMED+2023+type@asset+block/MATHML_md9_3_6.png)

# %% [markdown]
# > Одно из важных понятий, которое здесь появляется, — это **метод случайных подпространств**, который используется для построения ансамблей моделей.
#
# Кратко опишем его принцип:
#
# 1) Отбираем обучающую выборку.
# 2) Определяем число моделей, которые войдут в ансамбль.
# 3) Для каждой модели берём не все признаки, а только часть из них и формируем выборку с использованием случайно выбранного набора признаков.
# 4) Объединяем все результаты и определяем итоговое решение по объектам.

# %% [markdown]
# Алгоритм случайного леса в таком контексте реализуется следующим образом:
#
# 1) Для того чтобы построить $i$-е дерево леса, из обучающей выборки $X$ берём случайную подвыборку $X_i$ того же размера, что и вся обучающая выборка.
#
# 2) После этого в каждой вершине каждого дерева из $M$ возможных признаков выбираем случайную группу признаков объёма $L$. Для выбранных признаков ищем оптимальное разбиение. Рекомендуется использовать $L=\sqrt{M}$ в задачах классификации и $\frac{M}{3}$ — в задачах регрессии.
#
# 3) Для получения предсказания необходимо воспользоваться обычным принципом бэггинга: взять усреднённый ответ в случае регрессии или самый популярный класс — для классификации.

# %% [markdown]
# **Ошибка Out-of-Bag** — это способ оценить качество случайного леса.
#
# Для того чтобы найти *out-of-Bag*-оценку:
#
# 1) Для каждого объекта $x_i$ получаем предсказания всех деревьев $a_b$, обучавшихся на бутстреп-выборках $X_b$, не содержащих $x_i$.
#
# 2) Усредняем эти предсказания.
#
# 3) Находим значение ошибки для усреднённого предсказания.
#
# 4) Усредняем значение функционала ошибки для всех объектов выборки.

# %%
# Задание 3.4

data = pd.read_csv('data/boston (1).csv')
data.head()
# Out:
#   crim_rate  zn business  river nit_oxiden  rooms   age    dist  \
# 0   0,00632  18     2,31      0      0,538  6,575  65,2    4,09
# 1   0,02731   0     7,07      0      0,469  6,421  78,9  4,9671
# 2   0,02729   0     7,07      0      0,469  7,185  61,1  4,9671
# 3   0,03237   0     2,18      0      0,458  6,998  45,8  6,0622
# 4   0,06905   0     2,18      0      0,458  7,147  54,2  6,0622
#
#    highways_index  tax pup_per_teaс lower target
# 0               1  296         15,3  4,98     24
# 1               2  242         17,8  9,14   21,6
# 2               2  242         17,8  4,03   34,7
# 3               3  222         18,7  2,94   33,4
# 4               3  222         18,7  5,33   36,2

# %%
# # 1.

# import statistics

# X = data.drop('target', axis=1)
# y = data['target']
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state = 13)
# y_train.mean()

# %%
# # 2.

# from sklearn.linear_model import LinearRegression 
# from sklearn.metrics import mean_absolute_error as mae

# model_lr = LinearRegression()
# model_lr.fit(X_train, y_train)
# preds_train = model_lr.predict(X_train)
# preds_test = model_lr.predict(X_test)
# print(mae(y_test, preds_test))

# %%
# # 3.

# from sklearn.tree import DecisionTreeClassifier
# from sklearn.metrics import mean_absolute_error as mae

# model = DecisionTreeRegressor(random_state=13)
# model.fit(X_train, Y_train)
# preds_train = model.predict(X_train)
# preds_test = model.predict(X_test)
# print(mean_absolute_error(y_train, preds_train))
# print(mean_absolute_error(y_test, preds_test))

# %%
# # 4.

# from sklearn.ensemble import RandomForestClassifier

# for n in [3, 10, 100, 500]:
#     model = RandomForestRegressor(n_estimators=n, random_state = 13)
#     model.fit(X_train, y_train)
#     preds_train = model.predict(X_train)
#     preds_test = model.predict(X_test)
#     print(mean_absolute_error(y_test, preds_test))

# %%
df = pd.read_csv('data/weatherAUS.csv')
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1007.7       1007.1       8.0       NaN     16.9     21.8         No
# 1       1010.6       1007.8       NaN       NaN     17.2     24.3         No
# 2       1007.6       1008.7       NaN       2.0     21.0     23.2         No
# 3       1017.6       1012.8       NaN       NaN     18.1     26.5         No
# 4       1010.8       1006.0       7.0       8.0     17.8     29.7         No
#
#    RainTomorrow
# 0            No
# 1            No
# 2            No
# 3            No
# 4            No
#
# [5 rows x 23 columns]

# %%
# Задание 4.1

df.isnull().sum().sum()
# Out:
# 343248

# %%
# Задание 4.2

round(df.isna().sum() / len(df), 3)
# Out:
# Date             0.000
# Location         0.000
# MinTemp          0.010
# MaxTemp          0.009
# Rainfall         0.022
# Evaporation      0.432
# Sunshine         0.480
# WindGustDir      0.071
# WindGustSpeed    0.071
# WindDir9am       0.073
# WindDir3pm       0.029
# WindSpeed9am     0.012
# WindSpeed3pm     0.021
# Humidity9am      0.018
# Humidity3pm      0.031
# Pressure9am      0.104
# Pressure3pm      0.103
# Cloud9am         0.384
# Cloud3pm         0.408
# Temp9am          0.012
# Temp3pm          0.025
# RainToday        0.022
# RainTomorrow     0.022
# dtype: float64

# %%
df.drop(['Evaporation','Sunshine','Cloud3pm'], axis = 1, inplace = True)

# %%
# Задание 4.3

df.RainToday = df.RainToday.map({'No': 0, 'Yes': 1})

# %%
df.RainTomorrow = df.RainTomorrow.map({'No': 0, 'Yes': 1})

# %%
# Задание 4.4

df.Date = pd.to_datetime(df.Date)
df['Month'] = df.Date.dt.month
df.drop('Date', axis = 1, inplace = True)
df_season = df.groupby('Month').mean(numeric_only=True)
df_season[['RainToday']]
# Out:
#        RainToday
# Month
# 1       0.189484
# 2       0.206746
# 3       0.217135
# 4       0.216845
# 5       0.222163
# 6       0.263638
# 7       0.270736
# 8       0.253167
# 9       0.229135
# 10      0.196512
# 11      0.210843
# 12      0.213037

# %%
# Задание 4.5

categoricals = ['Month', 'Location', 'WindGustDir', 'WindDir9am', 'WindDir3pm']
df_dummies = pd.get_dummies(df, columns=categoricals)
df_dummies.shape
# Out:
# (145460, 124)

# %%
# Задание 4.6

df_dummies.dropna(inplace=True)
X = df_dummies.drop('RainTomorrow', axis = 1)
y = df_dummies['RainTomorrow']  
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state = 31)
y_test.mean()
# Out:
# 0.22770253002811142

# %%
# Задание 4.7

def gbs(data, n):     
    inds = np.random.randint(0, len(data), (n, len(data))) #определяем индексы случайным образом
    numbers = data[inds] #выбираем значения по индексам
    return numbers

# %%
target = X_train['MinTemp'].values #выбираем целевую переменную
np.random.seed(31) #задаём параметр генератора случайных чисел
mean_values = [np.mean(x) for x in gbs(target, 1000)] #получаем все средние значения
np.std(mean_values) #находим для них стандартное отклонение
# Out:
# 0.02879072820657669

# %%
# Задание 4.8

from sklearn.metrics import roc_auc_score

clf = LogisticRegression()
clf.fit(X_train, y_train)
preds_train = clf.predict(X_train)
preds_test = clf.predict(X_test)
roc_auc_score(y_test, preds_test)
# Out:
# c:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7265516156243416

# %%
# Задание 4.9

params = {
    'max_leaf_nodes': list(range(2, 10)), 
    'min_samples_split': [2, 3, 4], 
    'max_depth': [5,7,9,11]
}

# %%
from sklearn.model_selection import GridSearchCV

grid_search_cv = GridSearchCV(DecisionTreeClassifier(random_state=42), params, verbose=3, cv=3)
grid_search_cv.fit(X_train, y_train)
print(grid_search_cv.best_params_)
# Out:
# Fitting 3 folds for each of 96 candidates, totalling 288 fits
# [CV 1/3] END max_depth=5, max_leaf_nodes=2, min_samples_split=2;, score=0.817 total time=   0.0s
# [CV 2/3] END max_depth=5, max_leaf_nodes=2, min_samples_split=2;, score=0.820 total time=   0.0s
# [CV 3/3] END max_depth=5, max_leaf_nodes=2, min_samples_split=2;, score=0.825 total time=   0.0s
# [CV 1/3] END max_depth=5, max_leaf_nodes=2, min_samples_split=3;, score=0.817 total time=   0.0s
# [CV 2/3] END max_depth=5, max_leaf_nodes=2, min_samples_split=3;, score=0.820 total time=   0.0s
# [CV 3/3] END max_depth=5, max_leaf_nodes=2, min_samples_split=3;, score=0.825 total time=   0.0s
# [CV 1/3] END max_depth=5, max_leaf_nodes=2, min_samples_split=4;, score=0.817 total time=   0.0s
# [CV 2/3] END max_depth=5, max_leaf_nodes=2, min_samples_split=4;, score=0.820 total time=   0.0s
# [CV 3/3] END max_depth=5, max_leaf_nodes=2, min_samples_split=4;, score=0.825 total time=   0.0s
# [CV 1/3] END max_depth=5, max_leaf_nodes=3, min_samples_split=2;, score=0.819 total time=   0.0s
# [CV 2/3] END max_depth=5, max_leaf_nodes=3, min_samples_split=2;, score=0.820 total time=   0.0s
# [CV 3/3] END max_depth=5, max_leaf_nodes=3, min_samples_split=2;, score=0.825 total time=   0.0s
# [CV 1/3] END max_depth=5, max_leaf_nodes=3, min_samples_split=3;, score=0.819 total time=   0.0s
# [CV 2/3] END max_depth=5, max_leaf_nodes=3, min_samples_split=3;, score=0.820 total time=   0.0s
# [CV 3/3] END max_depth=5, max_leaf_nodes=3, min_samples_split=3;, score=0.825 total time=   0.0s
# [CV 1/3] END max_depth=5, max_leaf_nodes=3, min_samples_split=4;, score=0.819 total time=   0.0s
# [CV 2/3] END max_depth=5, max_leaf_nodes=3, min_samples_split=4;, score=0.820 total time=   0.0s
# [CV 3/3] END max_depth=5, max_leaf_nodes=3, min_samples_split=4;, score=0.825 total time=   0.0s
# [CV 1/3] END max_depth=5, max_leaf_nodes=4, min_samples_split=2;, score=0.819 total time=   0.0s
# [CV 2/3] END max_depth=5, max_leaf_nodes=4, min_samples_split=2;, score=0.820 total time=   0.0s
# [CV 3/3] END max_depth=5, max_leaf_nodes=4, min_samples_split=2;, score=0.825 total time=   0.0s
# [CV 1/3] END max_depth=5, max_leaf_nodes=4, min_samples_split=3;, score=0.819 total time=   0.0s
# [CV 2/3] END max_depth=5, max_leaf_nodes=4, min_samples_split=3;, score=0.820 total time=   0.0s
# [CV 3/3] END max_depth=5, max_leaf_nodes=4, min_samples_split=3;, score=0.825 total time=   0.0s
# [CV 1/3] END max_depth=5, max_leaf_nodes=4, min_samples_split=4;, score=0.819 total time=   0.0s
# [CV 2/3] END max_depth=5, max_leaf_nodes=4, min_samples_split=4;, score=0.820 total time=   0.0s
# [CV 3/3] END max_depth=5, max_leaf_nodes=4, min_samples_split=4;, score=0.825 total time=   0.0s
# [CV 1/3] END max_depth=5, max_leaf_nodes=5, min_samples_split=2;, score=0.819 total time=   0.0s
# [CV 2/3] END max_depth=5, max_leaf_nodes=5, min_samples_split=2;, score=0.820 total time=   0.0s
# [CV 3/3] END max_depth=5, max_leaf_nodes=5, min_samples_split=2;, score=0.825 total time=   0.0s
# [CV 1/3] END max_depth=5, max_leaf_nodes=5, min_samples_split=3;, score=0.819 total time=   0.0s
# [CV 2/3] END max_depth=5, max_leaf_nodes=5, min_samples_split=3;, score=0.820 total time=   0.0s
# [CV 3/3] END max_depth=5, max_leaf_nodes=5, min_samples_split=3;, score=0.825 total time=   0.0s
# [CV 1/3] END max_depth=5, max_leaf_nodes=5, min_samples_split=4;, score=0.819 total time=   0.0s
# [CV 2/3] END max_depth=5, max_leaf_nodes=5, min_samples_split=4;, score=0.820 total time=   0.0s
# [CV 3/3] END max_depth=5, max_leaf_nodes=5, min_samples_split=4;, score=0.825 total time=   0.0s
# [CV 1/3] END max_depth=5, max_leaf_nodes=6, min_samples_split=2;, score=0.819 total time=   0.1s
# [CV 2/3] END max_depth=5, max_leaf_nodes=6, min_samples_split=2;, score=0.820 total time=   0.0s
# [CV 3/3] END max_depth=5, max_leaf_nodes=6, min_samples_split=2;, score=0.832 total time=   0.1s
# [CV 1/3] END max_depth=5, max_leaf_nodes=6, min_samples_split=3;, score=0.819 total time=   0.0s
# [CV 2/3] END max_depth=5, max_leaf_nodes=6, min_samples_split=3;, score=0.820 total time=   0.1s
# [CV 3/3] END max_depth=5, max_leaf_nodes=6, min_samples_split=3;, score=0.832 total time=   0.0s
# [CV 1/3] END max_depth=5, max_leaf_nodes=6, min_samples_split=4;, score=0.819 total time=   0.0s
# [CV 2/3] END max_depth=5, max_leaf_nodes=6, min_samples_split=4;, score=0.820 total time=   0.1s
# [CV 3/3] END max_depth=5, max_leaf_nodes=6, min_samples_split=4;, score=0.832 total time=   0.0s
# [CV 1/3] END max_depth=5, max_leaf_nodes=7, min_samples_split=2;, score=0.831 total time=   0.0s
# [CV 2/3] END max_depth=5, max_leaf_nodes=7, min_samples_split=2;, score=0.834 total time=   0.1s
# [CV 3/3] END max_depth=5, max_leaf_nodes=7, min_samples_split=2;, score=0.832 total time=   0.0s
# [CV 1/3] END max_depth=5, max_leaf_nodes=7, min_samples_split=3;, score=0.831 total time=   0.0s
# [CV 2/3] END max_depth=5, max_leaf_nodes=7, min_samples_split=3;, score=0.834 total time=   0.1s
# [CV 3/3] END max_depth=5, max_leaf_nodes=7, min_samples_split=3;, score=0.832 total time=   0.0s
# [CV 1/3] END max_depth=5, max_leaf_nodes=7, min_samples_split=4;, score=0.831 total time=   0.0s
# [CV 2/3] END max_depth=5, max_leaf_nodes=7, min_samples_split=4;, score=0.834 total time=   0.1s
# [CV 3/3] END max_depth=5, max_leaf_nodes=7, min_samples_split=4;, score=0.832 total time=   0.0s
# [CV 1/3] END max_depth=5, max_leaf_nodes=8, min_samples_split=2;, score=0.835 total time=   0.1s
# [CV 2/3] END max_depth=5, max_leaf_nodes=8, min_samples_split=2;, score=0.840 total time=   0.0s
# [CV 3/3] END max_depth=5, max_leaf_nodes=8, min_samples_split=2;, score=0.836 total time=   0.1s
# [CV 1/3] END max_depth=5, max_leaf_nodes=8, min_samples_split=3;, score=0.835 total time=   0.1s
# [CV 2/3] END max_depth=5, max_leaf_nodes=8, min_samples_split=3;, score=0.840 total time=   0.1s
# [CV 3/3] END max_depth=5, max_leaf_nodes=8, min_samples_split=3;, score=0.836 total time=   0.1s
# [CV 1/3] END max_depth=5, max_leaf_nodes=8, min_samples_split=4;, score=0.835 total time=   0.1s
# [CV 2/3] END max_depth=5, max_leaf_nodes=8, min_samples_split=4;, score=0.840 total time=   0.1s
# [CV 3/3] END max_depth=5, max_leaf_nodes=8, min_samples_split=4;, score=0.836 total time=   0.0s
# [CV 1/3] END max_depth=5, max_leaf_nodes=9, min_samples_split=2;, score=0.835 total time=   0.1s
# [CV 2/3] END max_depth=5, max_leaf_nodes=9, min_samples_split=2;, score=0.840 total time=   0.1s
# [CV 3/3] END max_depth=5, max_leaf_nodes=9, min_samples_split=2;, score=0.837 total time=   0.1s
# [CV 1/3] END max_depth=5, max_leaf_nodes=9, min_samples_split=3;, score=0.835 total time=   0.1s
# [CV 2/3] END max_depth=5, max_leaf_nodes=9, min_samples_split=3;, score=0.840 total time=   0.1s
# [CV 3/3] END max_depth=5, max_leaf_nodes=9, min_samples_split=3;, score=0.837 total time=   0.1s
# [CV 1/3] END max_depth=5, max_leaf_nodes=9, min_samples_split=4;, score=0.835 total time=   0.1s
# [CV 2/3] END max_depth=5, max_leaf_nodes=9, min_samples_split=4;, score=0.840 total time=   0.1s
# [CV 3/3] END max_depth=5, max_leaf_nodes=9, min_samples_split=4;, score=0.837 total time=   0.1s
# [CV 1/3] END max_depth=7, max_leaf_nodes=2, min_samples_split=2;, score=0.817 total time=   0.0s
# [CV 2/3] END max_depth=7, max_leaf_nodes=2, min_samples_split=2;, score=0.820 total time=   0.0s
# [CV 3/3] END max_depth=7, max_leaf_nodes=2, min_samples_split=2;, score=0.825 total time=   0.0s
# [CV 1/3] END max_depth=7, max_leaf_nodes=2, min_samples_split=3;, score=0.817 total time=   0.0s
# [CV 2/3] END max_depth=7, max_leaf_nodes=2, min_samples_split=3;, score=0.820 total time=   0.0s
# [CV 3/3] END max_depth=7, max_leaf_nodes=2, min_samples_split=3;, score=0.825 total time=   0.0s
# [CV 1/3] END max_depth=7, max_leaf_nodes=2, min_samples_split=4;, score=0.817 total time=   0.0s
# [CV 2/3] END max_depth=7, max_leaf_nodes=2, min_samples_split=4;, score=0.820 total time=   0.0s
# [CV 3/3] END max_depth=7, max_leaf_nodes=2, min_samples_split=4;, score=0.825 total time=   0.0s
# [CV 1/3] END max_depth=7, max_leaf_nodes=3, min_samples_split=2;, score=0.819 total time=   0.0s
# [CV 2/3] END max_depth=7, max_leaf_nodes=3, min_samples_split=2;, score=0.820 total time=   0.0s
# [CV 3/3] END max_depth=7, max_leaf_nodes=3, min_samples_split=2;, score=0.825 total time=   0.0s
# [CV 1/3] END max_depth=7, max_leaf_nodes=3, min_samples_split=3;, score=0.819 total time=   0.0s
# [CV 2/3] END max_depth=7, max_leaf_nodes=3, min_samples_split=3;, score=0.820 total time=   0.0s
# [CV 3/3] END max_depth=7, max_leaf_nodes=3, min_samples_split=3;, score=0.825 total time=   0.0s
# [CV 1/3] END max_depth=7, max_leaf_nodes=3, min_samples_split=4;, score=0.819 total time=   0.0s
# [CV 2/3] END max_depth=7, max_leaf_nodes=3, min_samples_split=4;, score=0.820 total time=   0.0s
# [CV 3/3] END max_depth=7, max_leaf_nodes=3, min_samples_split=4;, score=0.825 total time=   0.0s
# [CV 1/3] END max_depth=7, max_leaf_nodes=4, min_samples_split=2;, score=0.819 total time=   0.0s
# [CV 2/3] END max_depth=7, max_leaf_nodes=4, min_samples_split=2;, score=0.820 total time=   0.0s
# [CV 3/3] END max_depth=7, max_leaf_nodes=4, min_samples_split=2;, score=0.825 total time=   0.0s
# [CV 1/3] END max_depth=7, max_leaf_nodes=4, min_samples_split=3;, score=0.819 total time=   0.0s
# [CV 2/3] END max_depth=7, max_leaf_nodes=4, min_samples_split=3;, score=0.820 total time=   0.0s
# [CV 3/3] END max_depth=7, max_leaf_nodes=4, min_samples_split=3;, score=0.825 total time=   0.0s
# [CV 1/3] END max_depth=7, max_leaf_nodes=4, min_samples_split=4;, score=0.819 total time=   0.0s
# [CV 2/3] END max_depth=7, max_leaf_nodes=4, min_samples_split=4;, score=0.820 total time=   0.0s
# [CV 3/3] END max_depth=7, max_leaf_nodes=4, min_samples_split=4;, score=0.825 total time=   0.0s
# [CV 1/3] END max_depth=7, max_leaf_nodes=5, min_samples_split=2;, score=0.819 total time=   0.0s
# [CV 2/3] END max_depth=7, max_leaf_nodes=5, min_samples_split=2;, score=0.820 total time=   0.0s
# [CV 3/3] END max_depth=7, max_leaf_nodes=5, min_samples_split=2;, score=0.825 total time=   0.0s
# [CV 1/3] END max_depth=7, max_leaf_nodes=5, min_samples_split=3;, score=0.819 total time=   0.0s
# [CV 2/3] END max_depth=7, max_leaf_nodes=5, min_samples_split=3;, score=0.820 total time=   0.0s
# [CV 3/3] END max_depth=7, max_leaf_nodes=5, min_samples_split=3;, score=0.825 total time=   0.0s
# [CV 1/3] END max_depth=7, max_leaf_nodes=5, min_samples_split=4;, score=0.819 total time=   0.0s
# [CV 2/3] END max_depth=7, max_leaf_nodes=5, min_samples_split=4;, score=0.820 total time=   0.0s
# [CV 3/3] END max_depth=7, max_leaf_nodes=5, min_samples_split=4;, score=0.825 total time=   0.0s
# [CV 1/3] END max_depth=7, max_leaf_nodes=6, min_samples_split=2;, score=0.819 total time=   0.0s
# [CV 2/3] END max_depth=7, max_leaf_nodes=6, min_samples_split=2;, score=0.820 total time=   0.0s
# [CV 3/3] END max_depth=7, max_leaf_nodes=6, min_samples_split=2;, score=0.832 total time=   0.0s
# [CV 1/3] END max_depth=7, max_leaf_nodes=6, min_samples_split=3;, score=0.819 total time=   0.0s
# [CV 2/3] END max_depth=7, max_leaf_nodes=6, min_samples_split=3;, score=0.820 total time=   0.0s
# [CV 3/3] END max_depth=7, max_leaf_nodes=6, min_samples_split=3;, score=0.832 total time=   0.0s
# [CV 1/3] END max_depth=7, max_leaf_nodes=6, min_samples_split=4;, score=0.819 total time=   0.0s
# [CV 2/3] END max_depth=7, max_leaf_nodes=6, min_samples_split=4;, score=0.820 total time=   0.0s
# [CV 3/3] END max_depth=7, max_leaf_nodes=6, min_samples_split=4;, score=0.832 total time=   0.0s
# [CV 1/3] END max_depth=7, max_leaf_nodes=7, min_samples_split=2;, score=0.831 total time=   0.1s
# [CV 2/3] END max_depth=7, max_leaf_nodes=7, min_samples_split=2;, score=0.834 total time=   0.1s
# [CV 3/3] END max_depth=7, max_leaf_nodes=7, min_samples_split=2;, score=0.832 total time=   0.1s
# [CV 1/3] END max_depth=7, max_leaf_nodes=7, min_samples_split=3;, score=0.831 total time=   0.1s
# [CV 2/3] END max_depth=7, max_leaf_nodes=7, min_samples_split=3;, score=0.834 total time=   0.1s
# [CV 3/3] END max_depth=7, max_leaf_nodes=7, min_samples_split=3;, score=0.832 total time=   0.1s
# [CV 1/3] END max_depth=7, max_leaf_nodes=7, min_samples_split=4;, score=0.831 total time=   0.1s
# [CV 2/3] END max_depth=7, max_leaf_nodes=7, min_samples_split=4;, score=0.834 total time=   0.1s
# [CV 3/3] END max_depth=7, max_leaf_nodes=7, min_samples_split=4;, score=0.832 total time=   0.1s
# [CV 1/3] END max_depth=7, max_leaf_nodes=8, min_samples_split=2;, score=0.835 total time=   0.1s
# [CV 2/3] END max_depth=7, max_leaf_nodes=8, min_samples_split=2;, score=0.840 total time=   0.1s
# [CV 3/3] END max_depth=7, max_leaf_nodes=8, min_samples_split=2;, score=0.836 total time=   0.0s
# [CV 1/3] END max_depth=7, max_leaf_nodes=8, min_samples_split=3;, score=0.835 total time=   0.1s
# [CV 2/3] END max_depth=7, max_leaf_nodes=8, min_samples_split=3;, score=0.840 total time=   0.1s
# [CV 3/3] END max_depth=7, max_leaf_nodes=8, min_samples_split=3;, score=0.836 total time=   0.1s
# [CV 1/3] END max_depth=7, max_leaf_nodes=8, min_samples_split=4;, score=0.835 total time=   0.1s
# [CV 2/3] END max_depth=7, max_leaf_nodes=8, min_samples_split=4;, score=0.840 total time=   0.1s
# [CV 3/3] END max_depth=7, max_leaf_nodes=8, min_samples_split=4;, score=0.836 total time=   0.1s
# [CV 1/3] END max_depth=7, max_leaf_nodes=9, min_samples_split=2;, score=0.835 total time=   0.1s
# [CV 2/3] END max_depth=7, max_leaf_nodes=9, min_samples_split=2;, score=0.840 total time=   0.1s
# [CV 3/3] END max_depth=7, max_leaf_nodes=9, min_samples_split=2;, score=0.837 total time=   0.1s
# [CV 1/3] END max_depth=7, max_leaf_nodes=9, min_samples_split=3;, score=0.835 total time=   0.1s
# [CV 2/3] END max_depth=7, max_leaf_nodes=9, min_samples_split=3;, score=0.840 total time=   0.1s
# [CV 3/3] END max_depth=7, max_leaf_nodes=9, min_samples_split=3;, score=0.837 total time=   0.1s
# [CV 1/3] END max_depth=7, max_leaf_nodes=9, min_samples_split=4;, score=0.835 total time=   0.1s
# [CV 2/3] END max_depth=7, max_leaf_nodes=9, min_samples_split=4;, score=0.840 total time=   0.1s
# [CV 3/3] END max_depth=7, max_leaf_nodes=9, min_samples_split=4;, score=0.837 total time=   0.1s
# [CV 1/3] END max_depth=9, max_leaf_nodes=2, min_samples_split=2;, score=0.817 total time=   0.0s
# [CV 2/3] END max_depth=9, max_leaf_nodes=2, min_samples_split=2;, score=0.820 total time=   0.0s
# [CV 3/3] END max_depth=9, max_leaf_nodes=2, min_samples_split=2;, score=0.825 total time=   0.0s
# [CV 1/3] END max_depth=9, max_leaf_nodes=2, min_samples_split=3;, score=0.817 total time=   0.0s
# [CV 2/3] END max_depth=9, max_leaf_nodes=2, min_samples_split=3;, score=0.820 total time=   0.0s
# [CV 3/3] END max_depth=9, max_leaf_nodes=2, min_samples_split=3;, score=0.825 total time=   0.0s
# [CV 1/3] END max_depth=9, max_leaf_nodes=2, min_samples_split=4;, score=0.817 total time=   0.0s
# [CV 2/3] END max_depth=9, max_leaf_nodes=2, min_samples_split=4;, score=0.820 total time=   0.0s
# [CV 3/3] END max_depth=9, max_leaf_nodes=2, min_samples_split=4;, score=0.825 total time=   0.0s
# [CV 1/3] END max_depth=9, max_leaf_nodes=3, min_samples_split=2;, score=0.819 total time=   0.0s
# [CV 2/3] END max_depth=9, max_leaf_nodes=3, min_samples_split=2;, score=0.820 total time=   0.0s
# [CV 3/3] END max_depth=9, max_leaf_nodes=3, min_samples_split=2;, score=0.825 total time=   0.0s
# [CV 1/3] END max_depth=9, max_leaf_nodes=3, min_samples_split=3;, score=0.819 total time=   0.0s
# [CV 2/3] END max_depth=9, max_leaf_nodes=3, min_samples_split=3;, score=0.820 total time=   0.0s
# [CV 3/3] END max_depth=9, max_leaf_nodes=3, min_samples_split=3;, score=0.825 total time=   0.0s
# [CV 1/3] END max_depth=9, max_leaf_nodes=3, min_samples_split=4;, score=0.819 total time=   0.0s
# [CV 2/3] END max_depth=9, max_leaf_nodes=3, min_samples_split=4;, score=0.820 total time=   0.0s
# [CV 3/3] END max_depth=9, max_leaf_nodes=3, min_samples_split=4;, score=0.825 total time=   0.0s
# [CV 1/3] END max_depth=9, max_leaf_nodes=4, min_samples_split=2;, score=0.819 total time=   0.0s
# [CV 2/3] END max_depth=9, max_leaf_nodes=4, min_samples_split=2;, score=0.820 total time=   0.0s
# [CV 3/3] END max_depth=9, max_leaf_nodes=4, min_samples_split=2;, score=0.825 total time=   0.0s
# [CV 1/3] END max_depth=9, max_leaf_nodes=4, min_samples_split=3;, score=0.819 total time=   0.0s
# [CV 2/3] END max_depth=9, max_leaf_nodes=4, min_samples_split=3;, score=0.820 total time=   0.0s
# [CV 3/3] END max_depth=9, max_leaf_nodes=4, min_samples_split=3;, score=0.825 total time=   0.0s
# [CV 1/3] END max_depth=9, max_leaf_nodes=4, min_samples_split=4;, score=0.819 total time=   0.0s
# [CV 2/3] END max_depth=9, max_leaf_nodes=4, min_samples_split=4;, score=0.820 total time=   0.0s
# [CV 3/3] END max_depth=9, max_leaf_nodes=4, min_samples_split=4;, score=0.825 total time=   0.0s
# [CV 1/3] END max_depth=9, max_leaf_nodes=5, min_samples_split=2;, score=0.819 total time=   0.0s
# [CV 2/3] END max_depth=9, max_leaf_nodes=5, min_samples_split=2;, score=0.820 total time=   0.0s
# [CV 3/3] END max_depth=9, max_leaf_nodes=5, min_samples_split=2;, score=0.825 total time=   0.0s
# [CV 1/3] END max_depth=9, max_leaf_nodes=5, min_samples_split=3;, score=0.819 total time=   0.0s
# [CV 2/3] END max_depth=9, max_leaf_nodes=5, min_samples_split=3;, score=0.820 total time=   0.0s
# [CV 3/3] END max_depth=9, max_leaf_nodes=5, min_samples_split=3;, score=0.825 total time=   0.0s
# [CV 1/3] END max_depth=9, max_leaf_nodes=5, min_samples_split=4;, score=0.819 total time=   0.0s
# [CV 2/3] END max_depth=9, max_leaf_nodes=5, min_samples_split=4;, score=0.820 total time=   0.0s
# [CV 3/3] END max_depth=9, max_leaf_nodes=5, min_samples_split=4;, score=0.825 total time=   0.0s
# [CV 1/3] END max_depth=9, max_leaf_nodes=6, min_samples_split=2;, score=0.819 total time=   0.0s
# [CV 2/3] END max_depth=9, max_leaf_nodes=6, min_samples_split=2;, score=0.820 total time=   0.0s
# [CV 3/3] END max_depth=9, max_leaf_nodes=6, min_samples_split=2;, score=0.832 total time=   0.0s
# [CV 1/3] END max_depth=9, max_leaf_nodes=6, min_samples_split=3;, score=0.819 total time=   0.1s
# [CV 2/3] END max_depth=9, max_leaf_nodes=6, min_samples_split=3;, score=0.820 total time=   0.0s
# [CV 3/3] END max_depth=9, max_leaf_nodes=6, min_samples_split=3;, score=0.832 total time=   0.0s
# [CV 1/3] END max_depth=9, max_leaf_nodes=6, min_samples_split=4;, score=0.819 total time=   0.0s
# [CV 2/3] END max_depth=9, max_leaf_nodes=6, min_samples_split=4;, score=0.820 total time=   0.0s
# [CV 3/3] END max_depth=9, max_leaf_nodes=6, min_samples_split=4;, score=0.832 total time=   0.0s
# [CV 1/3] END max_depth=9, max_leaf_nodes=7, min_samples_split=2;, score=0.831 total time=   0.1s
# [CV 2/3] END max_depth=9, max_leaf_nodes=7, min_samples_split=2;, score=0.834 total time=   0.1s
# [CV 3/3] END max_depth=9, max_leaf_nodes=7, min_samples_split=2;, score=0.832 total time=   0.0s
# [CV 1/3] END max_depth=9, max_leaf_nodes=7, min_samples_split=3;, score=0.831 total time=   0.1s
# [CV 2/3] END max_depth=9, max_leaf_nodes=7, min_samples_split=3;, score=0.834 total time=   0.1s
# [CV 3/3] END max_depth=9, max_leaf_nodes=7, min_samples_split=3;, score=0.832 total time=   0.1s
# [CV 1/3] END max_depth=9, max_leaf_nodes=7, min_samples_split=4;, score=0.831 total time=   0.1s
# [CV 2/3] END max_depth=9, max_leaf_nodes=7, min_samples_split=4;, score=0.834 total time=   0.1s
# [CV 3/3] END max_depth=9, max_leaf_nodes=7, min_samples_split=4;, score=0.832 total time=   0.1s
# [CV 1/3] END max_depth=9, max_leaf_nodes=8, min_samples_split=2;, score=0.835 total time=   0.1s
# [CV 2/3] END max_depth=9, max_leaf_nodes=8, min_samples_split=2;, score=0.840 total time=   0.1s
# [CV 3/3] END max_depth=9, max_leaf_nodes=8, min_samples_split=2;, score=0.836 total time=   0.1s
# [CV 1/3] END max_depth=9, max_leaf_nodes=8, min_samples_split=3;, score=0.835 total time=   0.1s
# [CV 2/3] END max_depth=9, max_leaf_nodes=8, min_samples_split=3;, score=0.840 total time=   0.1s
# [CV 3/3] END max_depth=9, max_leaf_nodes=8, min_samples_split=3;, score=0.836 total time=   0.1s
# [CV 1/3] END max_depth=9, max_leaf_nodes=8, min_samples_split=4;, score=0.835 total time=   0.1s
# [CV 2/3] END max_depth=9, max_leaf_nodes=8, min_samples_split=4;, score=0.840 total time=   0.1s
# [CV 3/3] END max_depth=9, max_leaf_nodes=8, min_samples_split=4;, score=0.836 total time=   0.1s
# [CV 1/3] END max_depth=9, max_leaf_nodes=9, min_samples_split=2;, score=0.835 total time=   0.1s
# [CV 2/3] END max_depth=9, max_leaf_nodes=9, min_samples_split=2;, score=0.840 total time=   0.1s
# [CV 3/3] END max_depth=9, max_leaf_nodes=9, min_samples_split=2;, score=0.837 total time=   0.1s
# [CV 1/3] END max_depth=9, max_leaf_nodes=9, min_samples_split=3;, score=0.835 total time=   0.1s
# [CV 2/3] END max_depth=9, max_leaf_nodes=9, min_samples_split=3;, score=0.840 total time=   0.1s
# [CV 3/3] END max_depth=9, max_leaf_nodes=9, min_samples_split=3;, score=0.837 total time=   0.1s
# [CV 1/3] END max_depth=9, max_leaf_nodes=9, min_samples_split=4;, score=0.835 total time=   0.1s
# [CV 2/3] END max_depth=9, max_leaf_nodes=9, min_samples_split=4;, score=0.840 total time=   0.1s
# [CV 3/3] END max_depth=9, max_leaf_nodes=9, min_samples_split=4;, score=0.837 total time=   0.1s
# [CV 1/3] END max_depth=11, max_leaf_nodes=2, min_samples_split=2;, score=0.817 total time=   0.0s
# [CV 2/3] END max_depth=11, max_leaf_nodes=2, min_samples_split=2;, score=0.820 total time=   0.0s
# [CV 3/3] END max_depth=11, max_leaf_nodes=2, min_samples_split=2;, score=0.825 total time=   0.0s
# [CV 1/3] END max_depth=11, max_leaf_nodes=2, min_samples_split=3;, score=0.817 total time=   0.0s
# [CV 2/3] END max_depth=11, max_leaf_nodes=2, min_samples_split=3;, score=0.820 total time=   0.0s
# [CV 3/3] END max_depth=11, max_leaf_nodes=2, min_samples_split=3;, score=0.825 total time=   0.0s
# [CV 1/3] END max_depth=11, max_leaf_nodes=2, min_samples_split=4;, score=0.817 total time=   0.0s
# [CV 2/3] END max_depth=11, max_leaf_nodes=2, min_samples_split=4;, score=0.820 total time=   0.0s
# [CV 3/3] END max_depth=11, max_leaf_nodes=2, min_samples_split=4;, score=0.825 total time=   0.0s
# [CV 1/3] END max_depth=11, max_leaf_nodes=3, min_samples_split=2;, score=0.819 total time=   0.0s
# [CV 2/3] END max_depth=11, max_leaf_nodes=3, min_samples_split=2;, score=0.820 total time=   0.0s
# [CV 3/3] END max_depth=11, max_leaf_nodes=3, min_samples_split=2;, score=0.825 total time=   0.0s
# [CV 1/3] END max_depth=11, max_leaf_nodes=3, min_samples_split=3;, score=0.819 total time=   0.0s
# [CV 2/3] END max_depth=11, max_leaf_nodes=3, min_samples_split=3;, score=0.820 total time=   0.0s
# [CV 3/3] END max_depth=11, max_leaf_nodes=3, min_samples_split=3;, score=0.825 total time=   0.0s
# [CV 1/3] END max_depth=11, max_leaf_nodes=3, min_samples_split=4;, score=0.819 total time=   0.0s
# [CV 2/3] END max_depth=11, max_leaf_nodes=3, min_samples_split=4;, score=0.820 total time=   0.0s
# [CV 3/3] END max_depth=11, max_leaf_nodes=3, min_samples_split=4;, score=0.825 total time=   0.0s
# [CV 1/3] END max_depth=11, max_leaf_nodes=4, min_samples_split=2;, score=0.819 total time=   0.0s
# [CV 2/3] END max_depth=11, max_leaf_nodes=4, min_samples_split=2;, score=0.820 total time=   0.0s
# [CV 3/3] END max_depth=11, max_leaf_nodes=4, min_samples_split=2;, score=0.825 total time=   0.0s
# [CV 1/3] END max_depth=11, max_leaf_nodes=4, min_samples_split=3;, score=0.819 total time=   0.0s
# [CV 2/3] END max_depth=11, max_leaf_nodes=4, min_samples_split=3;, score=0.820 total time=   0.0s
# [CV 3/3] END max_depth=11, max_leaf_nodes=4, min_samples_split=3;, score=0.825 total time=   0.0s
# [CV 1/3] END max_depth=11, max_leaf_nodes=4, min_samples_split=4;, score=0.819 total time=   0.0s
# [CV 2/3] END max_depth=11, max_leaf_nodes=4, min_samples_split=4;, score=0.820 total time=   0.0s
# [CV 3/3] END max_depth=11, max_leaf_nodes=4, min_samples_split=4;, score=0.825 total time=   0.0s
# [CV 1/3] END max_depth=11, max_leaf_nodes=5, min_samples_split=2;, score=0.819 total time=   0.0s
# [CV 2/3] END max_depth=11, max_leaf_nodes=5, min_samples_split=2;, score=0.820 total time=   0.0s
# [CV 3/3] END max_depth=11, max_leaf_nodes=5, min_samples_split=2;, score=0.825 total time=   0.0s
# [CV 1/3] END max_depth=11, max_leaf_nodes=5, min_samples_split=3;, score=0.819 total time=   0.0s
# [CV 2/3] END max_depth=11, max_leaf_nodes=5, min_samples_split=3;, score=0.820 total time=   0.0s
# [CV 3/3] END max_depth=11, max_leaf_nodes=5, min_samples_split=3;, score=0.825 total time=   0.0s
# [CV 1/3] END max_depth=11, max_leaf_nodes=5, min_samples_split=4;, score=0.819 total time=   0.0s
# [CV 2/3] END max_depth=11, max_leaf_nodes=5, min_samples_split=4;, score=0.820 total time=   0.0s
# [CV 3/3] END max_depth=11, max_leaf_nodes=5, min_samples_split=4;, score=0.825 total time=   0.0s
# [CV 1/3] END max_depth=11, max_leaf_nodes=6, min_samples_split=2;, score=0.819 total time=   0.0s
# [CV 2/3] END max_depth=11, max_leaf_nodes=6, min_samples_split=2;, score=0.820 total time=   0.0s
# [CV 3/3] END max_depth=11, max_leaf_nodes=6, min_samples_split=2;, score=0.832 total time=   0.0s
# [CV 1/3] END max_depth=11, max_leaf_nodes=6, min_samples_split=3;, score=0.819 total time=   0.1s
# [CV 2/3] END max_depth=11, max_leaf_nodes=6, min_samples_split=3;, score=0.820 total time=   0.0s
# [CV 3/3] END max_depth=11, max_leaf_nodes=6, min_samples_split=3;, score=0.832 total time=   0.0s
# [CV 1/3] END max_depth=11, max_leaf_nodes=6, min_samples_split=4;, score=0.819 total time=   0.0s
# [CV 2/3] END max_depth=11, max_leaf_nodes=6, min_samples_split=4;, score=0.820 total time=   0.0s
# [CV 3/3] END max_depth=11, max_leaf_nodes=6, min_samples_split=4;, score=0.832 total time=   0.0s
# [CV 1/3] END max_depth=11, max_leaf_nodes=7, min_samples_split=2;, score=0.831 total time=   0.1s
# [CV 2/3] END max_depth=11, max_leaf_nodes=7, min_samples_split=2;, score=0.834 total time=   0.1s
# [CV 3/3] END max_depth=11, max_leaf_nodes=7, min_samples_split=2;, score=0.832 total time=   0.1s
# [CV 1/3] END max_depth=11, max_leaf_nodes=7, min_samples_split=3;, score=0.831 total time=   0.1s
# [CV 2/3] END max_depth=11, max_leaf_nodes=7, min_samples_split=3;, score=0.834 total time=   0.0s
# [CV 3/3] END max_depth=11, max_leaf_nodes=7, min_samples_split=3;, score=0.832 total time=   0.1s
# [CV 1/3] END max_depth=11, max_leaf_nodes=7, min_samples_split=4;, score=0.831 total time=   0.1s
# [CV 2/3] END max_depth=11, max_leaf_nodes=7, min_samples_split=4;, score=0.834 total time=   0.0s
# [CV 3/3] END max_depth=11, max_leaf_nodes=7, min_samples_split=4;, score=0.832 total time=   0.0s
# [CV 1/3] END max_depth=11, max_leaf_nodes=8, min_samples_split=2;, score=0.835 total time=   0.1s
# [CV 2/3] END max_depth=11, max_leaf_nodes=8, min_samples_split=2;, score=0.840 total time=   0.1s
# [CV 3/3] END max_depth=11, max_leaf_nodes=8, min_samples_split=2;, score=0.836 total time=   0.1s
# [CV 1/3] END max_depth=11, max_leaf_nodes=8, min_samples_split=3;, score=0.835 total time=   0.1s
# [CV 2/3] END max_depth=11, max_leaf_nodes=8, min_samples_split=3;, score=0.840 total time=   0.1s
# [CV 3/3] END max_depth=11, max_leaf_nodes=8, min_samples_split=3;, score=0.836 total time=   0.0s
# [CV 1/3] END max_depth=11, max_leaf_nodes=8, min_samples_split=4;, score=0.835 total time=   0.0s
# [CV 2/3] END max_depth=11, max_leaf_nodes=8, min_samples_split=4;, score=0.840 total time=   0.1s
# [CV 3/3] END max_depth=11, max_leaf_nodes=8, min_samples_split=4;, score=0.836 total time=   0.1s
# [CV 1/3] END max_depth=11, max_leaf_nodes=9, min_samples_split=2;, score=0.835 total time=   0.1s
# [CV 2/3] END max_depth=11, max_leaf_nodes=9, min_samples_split=2;, score=0.840 total time=   0.1s
# [CV 3/3] END max_depth=11, max_leaf_nodes=9, min_samples_split=2;, score=0.837 total time=   0.1s
# [CV 1/3] END max_depth=11, max_leaf_nodes=9, min_samples_split=3;, score=0.835 total time=   0.1s
# [CV 2/3] END max_depth=11, max_leaf_nodes=9, min_samples_split=3;, score=0.840 total time=   0.1s
# [CV 3/3] END max_depth=11, max_leaf_nodes=9, min_samples_split=3;, score=0.837 total time=   0.1s
# [CV 1/3] END max_depth=11, max_leaf_nodes=9, min_samples_split=4;, score=0.835 total time=   0.1s
# [CV 2/3] END max_depth=11, max_leaf_nodes=9, min_samples_split=4;, score=0.840 total time=   0.1s
# [CV 3/3] END max_depth=11, max_leaf_nodes=9, min_samples_split=4;, score=0.837 total time=   0.1s
# {'max_depth': 5, 'max_leaf_nodes': 9, 'min_samples_split': 2}

# %%
clf = DecisionTreeClassifier(max_depth = 5, max_leaf_nodes = 9, min_samples_split = 2, random_state=42)
clf.fit(X_train, y_train)
preds_train = clf.predict(X_train)
preds_test = clf.predict(X_test)
print(round(roc_auc_score(y_test, preds_test), 2))
# Out:
# 0.7

# %%
# Задание 4.10

from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(n_estimators = 100, random_state=31)
clf.fit(X_train, y_train)
preds_train = clf.predict(X_train)
preds_test = clf.predict(X_test)
print(round(roc_auc_score(y_test, preds_test), 2))
# Out:
# 0.73

# %%
# Задание 4.11

params = {
    'max_features': [4, 5, 6, 7], 
    'min_samples_leaf': [3, 5, 7, 9, 11], 
    'max_depth': [5, 10, 15]
}

# %%
grid_search_cv = GridSearchCV(RandomForestClassifier(random_state=31), params, verbose=3, cv=3)
grid_search_cv.fit(X_train, y_train)
print(grid_search_cv.best_params_)
# Out:
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# [CV 1/3] END max_depth=5, max_features=4, min_samples_leaf=3;, score=0.776 total time=   0.7s
# [CV 2/3] END max_depth=5, max_features=4, min_samples_leaf=3;, score=0.775 total time=   0.7s
# [CV 3/3] END max_depth=5, max_features=4, min_samples_leaf=3;, score=0.775 total time=   0.7s
# [CV 1/3] END max_depth=5, max_features=4, min_samples_leaf=5;, score=0.776 total time=   0.7s
# [CV 2/3] END max_depth=5, max_features=4, min_samples_leaf=5;, score=0.775 total time=   0.7s
# [CV 3/3] END max_depth=5, max_features=4, min_samples_leaf=5;, score=0.775 total time=   0.7s
# [CV 1/3] END max_depth=5, max_features=4, min_samples_leaf=7;, score=0.776 total time=   0.7s
# [CV 2/3] END max_depth=5, max_features=4, min_samples_leaf=7;, score=0.775 total time=   0.7s
# [CV 3/3] END max_depth=5, max_features=4, min_samples_leaf=7;, score=0.775 total time=   0.7s
# [CV 1/3] END max_depth=5, max_features=4, min_samples_leaf=9;, score=0.776 total time=   0.6s
# [CV 2/3] END max_depth=5, max_features=4, min_samples_leaf=9;, score=0.775 total time=   0.7s
# [CV 3/3] END max_depth=5, max_features=4, min_samples_leaf=9;, score=0.775 total time=   0.7s
# [CV 1/3] END max_depth=5, max_features=4, min_samples_leaf=11;, score=0.776 total time=   0.7s
# [CV 2/3] END max_depth=5, max_features=4, min_samples_leaf=11;, score=0.775 total time=   0.7s
# [CV 3/3] END max_depth=5, max_features=4, min_samples_leaf=11;, score=0.775 total time=   0.7s
# [CV 1/3] END max_depth=5, max_features=5, min_samples_leaf=3;, score=0.782 total time=   0.8s
# [CV 2/3] END max_depth=5, max_features=5, min_samples_leaf=3;, score=0.780 total time=   0.8s
# [CV 3/3] END max_depth=5, max_features=5, min_samples_leaf=3;, score=0.781 total time=   0.8s
# [CV 1/3] END max_depth=5, max_features=5, min_samples_leaf=5;, score=0.781 total time=   0.8s
# [CV 2/3] END max_depth=5, max_features=5, min_samples_leaf=5;, score=0.781 total time=   0.8s
# [CV 3/3] END max_depth=5, max_features=5, min_samples_leaf=5;, score=0.781 total time=   0.8s
# [CV 1/3] END max_depth=5, max_features=5, min_samples_leaf=7;, score=0.782 total time=   0.8s
# [CV 2/3] END max_depth=5, max_features=5, min_samples_leaf=7;, score=0.780 total time=   0.7s
# [CV 3/3] END max_depth=5, max_features=5, min_samples_leaf=7;, score=0.782 total time=   0.8s
# [CV 1/3] END max_depth=5, max_features=5, min_samples_leaf=9;, score=0.782 total time=   0.8s
# [CV 2/3] END max_depth=5, max_features=5, min_samples_leaf=9;, score=0.779 total time=   0.7s
# [CV 3/3] END max_depth=5, max_features=5, min_samples_leaf=9;, score=0.781 total time=   0.7s
# [CV 1/3] END max_depth=5, max_features=5, min_samples_leaf=11;, score=0.784 total time=   0.8s
# [CV 2/3] END max_depth=5, max_features=5, min_samples_leaf=11;, score=0.781 total time=   0.7s
# [CV 3/3] END max_depth=5, max_features=5, min_samples_leaf=11;, score=0.783 total time=   0.8s
# [CV 1/3] END max_depth=5, max_features=6, min_samples_leaf=3;, score=0.795 total time=   0.8s
# [CV 2/3] END max_depth=5, max_features=6, min_samples_leaf=3;, score=0.793 total time=   0.8s
# [CV 3/3] END max_depth=5, max_features=6, min_samples_leaf=3;, score=0.796 total time=   0.8s
# [CV 1/3] END max_depth=5, max_features=6, min_samples_leaf=5;, score=0.793 total time=   0.8s
# [CV 2/3] END max_depth=5, max_features=6, min_samples_leaf=5;, score=0.792 total time=   0.8s
# [CV 3/3] END max_depth=5, max_features=6, min_samples_leaf=5;, score=0.795 total time=   0.8s
# [CV 1/3] END max_depth=5, max_features=6, min_samples_leaf=7;, score=0.798 total time=   0.8s
# [CV 2/3] END max_depth=5, max_features=6, min_samples_leaf=7;, score=0.794 total time=   0.8s
# [CV 3/3] END max_depth=5, max_features=6, min_samples_leaf=7;, score=0.795 total time=   0.8s
# [CV 1/3] END max_depth=5, max_features=6, min_samples_leaf=9;, score=0.796 total time=   0.8s
# [CV 2/3] END max_depth=5, max_features=6, min_samples_leaf=9;, score=0.795 total time=   0.8s
# [CV 3/3] END max_depth=5, max_features=6, min_samples_leaf=9;, score=0.795 total time=   0.8s
# [CV 1/3] END max_depth=5, max_features=6, min_samples_leaf=11;, score=0.795 total time=   0.8s
# [CV 2/3] END max_depth=5, max_features=6, min_samples_leaf=11;, score=0.798 total time=   0.8s
# [CV 3/3] END max_depth=5, max_features=6, min_samples_leaf=11;, score=0.795 total time=   0.8s
# [CV 1/3] END max_depth=5, max_features=7, min_samples_leaf=3;, score=0.798 total time=   0.9s
# [CV 2/3] END max_depth=5, max_features=7, min_samples_leaf=3;, score=0.801 total time=   0.9s
# [CV 3/3] END max_depth=5, max_features=7, min_samples_leaf=3;, score=0.794 total time=   0.9s
# [CV 1/3] END max_depth=5, max_features=7, min_samples_leaf=5;, score=0.798 total time=   0.9s
# [CV 2/3] END max_depth=5, max_features=7, min_samples_leaf=5;, score=0.801 total time=   0.9s
# [CV 3/3] END max_depth=5, max_features=7, min_samples_leaf=5;, score=0.797 total time=   1.0s
# [CV 1/3] END max_depth=5, max_features=7, min_samples_leaf=7;, score=0.794 total time=   0.9s
# [CV 2/3] END max_depth=5, max_features=7, min_samples_leaf=7;, score=0.800 total time=   0.9s
# [CV 3/3] END max_depth=5, max_features=7, min_samples_leaf=7;, score=0.795 total time=   0.9s
# [CV 1/3] END max_depth=5, max_features=7, min_samples_leaf=9;, score=0.796 total time=   0.9s
# [CV 2/3] END max_depth=5, max_features=7, min_samples_leaf=9;, score=0.800 total time=   0.9s
# [CV 3/3] END max_depth=5, max_features=7, min_samples_leaf=9;, score=0.795 total time=   0.9s
# [CV 1/3] END max_depth=5, max_features=7, min_samples_leaf=11;, score=0.796 total time=   0.9s
# [CV 2/3] END max_depth=5, max_features=7, min_samples_leaf=11;, score=0.803 total time=   0.9s
# [CV 3/3] END max_depth=5, max_features=7, min_samples_leaf=11;, score=0.795 total time=   1.0s
# [CV 1/3] END max_depth=10, max_features=4, min_samples_leaf=3;, score=0.810 total time=   1.2s
# [CV 2/3] END max_depth=10, max_features=4, min_samples_leaf=3;, score=0.815 total time=   1.2s
# [CV 3/3] END max_depth=10, max_features=4, min_samples_leaf=3;, score=0.813 total time=   1.2s
# [CV 1/3] END max_depth=10, max_features=4, min_samples_leaf=5;, score=0.812 total time=   1.2s
# [CV 2/3] END max_depth=10, max_features=4, min_samples_leaf=5;, score=0.811 total time=   1.2s
# [CV 3/3] END max_depth=10, max_features=4, min_samples_leaf=5;, score=0.813 total time=   1.2s
# [CV 1/3] END max_depth=10, max_features=4, min_samples_leaf=7;, score=0.811 total time=   1.2s
# [CV 2/3] END max_depth=10, max_features=4, min_samples_leaf=7;, score=0.812 total time=   1.2s
# [CV 3/3] END max_depth=10, max_features=4, min_samples_leaf=7;, score=0.812 total time=   1.2s
# [CV 1/3] END max_depth=10, max_features=4, min_samples_leaf=9;, score=0.809 total time=   1.2s
# [CV 2/3] END max_depth=10, max_features=4, min_samples_leaf=9;, score=0.812 total time=   1.1s
# [CV 3/3] END max_depth=10, max_features=4, min_samples_leaf=9;, score=0.811 total time=   1.2s
# [CV 1/3] END max_depth=10, max_features=4, min_samples_leaf=11;, score=0.813 total time=   1.2s
# [CV 2/3] END max_depth=10, max_features=4, min_samples_leaf=11;, score=0.812 total time=   1.1s
# [CV 3/3] END max_depth=10, max_features=4, min_samples_leaf=11;, score=0.813 total time=   1.2s
# [CV 1/3] END max_depth=10, max_features=5, min_samples_leaf=3;, score=0.819 total time=   1.4s
# [CV 2/3] END max_depth=10, max_features=5, min_samples_leaf=3;, score=0.826 total time=   1.4s
# [CV 3/3] END max_depth=10, max_features=5, min_samples_leaf=3;, score=0.820 total time=   1.4s
# [CV 1/3] END max_depth=10, max_features=5, min_samples_leaf=5;, score=0.821 total time=   1.4s
# [CV 2/3] END max_depth=10, max_features=5, min_samples_leaf=5;, score=0.826 total time=   1.4s
# [CV 3/3] END max_depth=10, max_features=5, min_samples_leaf=5;, score=0.820 total time=   1.4s
# [CV 1/3] END max_depth=10, max_features=5, min_samples_leaf=7;, score=0.820 total time=   1.4s
# [CV 2/3] END max_depth=10, max_features=5, min_samples_leaf=7;, score=0.819 total time=   1.3s
# [CV 3/3] END max_depth=10, max_features=5, min_samples_leaf=7;, score=0.820 total time=   1.4s
# [CV 1/3] END max_depth=10, max_features=5, min_samples_leaf=9;, score=0.819 total time=   1.3s
# [CV 2/3] END max_depth=10, max_features=5, min_samples_leaf=9;, score=0.824 total time=   1.4s
# [CV 3/3] END max_depth=10, max_features=5, min_samples_leaf=9;, score=0.816 total time=   1.3s
# [CV 1/3] END max_depth=10, max_features=5, min_samples_leaf=11;, score=0.822 total time=   1.3s
# [CV 2/3] END max_depth=10, max_features=5, min_samples_leaf=11;, score=0.826 total time=   1.3s
# [CV 3/3] END max_depth=10, max_features=5, min_samples_leaf=11;, score=0.817 total time=   1.3s
# [CV 1/3] END max_depth=10, max_features=6, min_samples_leaf=3;, score=0.832 total time=   1.6s
# [CV 2/3] END max_depth=10, max_features=6, min_samples_leaf=3;, score=0.834 total time=   1.5s
# [CV 3/3] END max_depth=10, max_features=6, min_samples_leaf=3;, score=0.830 total time=   1.6s
# [CV 1/3] END max_depth=10, max_features=6, min_samples_leaf=5;, score=0.829 total time=   1.5s
# [CV 2/3] END max_depth=10, max_features=6, min_samples_leaf=5;, score=0.835 total time=   1.6s
# [CV 3/3] END max_depth=10, max_features=6, min_samples_leaf=5;, score=0.828 total time=   1.5s
# [CV 1/3] END max_depth=10, max_features=6, min_samples_leaf=7;, score=0.831 total time=   1.5s
# [CV 2/3] END max_depth=10, max_features=6, min_samples_leaf=7;, score=0.835 total time=   1.5s
# [CV 3/3] END max_depth=10, max_features=6, min_samples_leaf=7;, score=0.831 total time=   1.5s
# [CV 1/3] END max_depth=10, max_features=6, min_samples_leaf=9;, score=0.830 total time=   1.5s
# [CV 2/3] END max_depth=10, max_features=6, min_samples_leaf=9;, score=0.835 total time=   1.6s
# [CV 3/3] END max_depth=10, max_features=6, min_samples_leaf=9;, score=0.831 total time=   1.6s
# [CV 1/3] END max_depth=10, max_features=6, min_samples_leaf=11;, score=0.831 total time=   1.6s
# [CV 2/3] END max_depth=10, max_features=6, min_samples_leaf=11;, score=0.835 total time=   1.5s
# [CV 3/3] END max_depth=10, max_features=6, min_samples_leaf=11;, score=0.827 total time=   1.5s
# [CV 1/3] END max_depth=10, max_features=7, min_samples_leaf=3;, score=0.833 total time=   1.8s
# [CV 2/3] END max_depth=10, max_features=7, min_samples_leaf=3;, score=0.839 total time=   1.8s
# [CV 3/3] END max_depth=10, max_features=7, min_samples_leaf=3;, score=0.831 total time=   1.8s
# [CV 1/3] END max_depth=10, max_features=7, min_samples_leaf=5;, score=0.834 total time=   1.7s
# [CV 2/3] END max_depth=10, max_features=7, min_samples_leaf=5;, score=0.838 total time=   1.7s
# [CV 3/3] END max_depth=10, max_features=7, min_samples_leaf=5;, score=0.832 total time=   1.8s
# [CV 1/3] END max_depth=10, max_features=7, min_samples_leaf=7;, score=0.831 total time=   1.7s
# [CV 2/3] END max_depth=10, max_features=7, min_samples_leaf=7;, score=0.838 total time=   1.7s
# [CV 3/3] END max_depth=10, max_features=7, min_samples_leaf=7;, score=0.829 total time=   1.7s
# [CV 1/3] END max_depth=10, max_features=7, min_samples_leaf=9;, score=0.833 total time=   1.7s
# [CV 2/3] END max_depth=10, max_features=7, min_samples_leaf=9;, score=0.838 total time=   1.7s
# [CV 3/3] END max_depth=10, max_features=7, min_samples_leaf=9;, score=0.831 total time=   1.7s
# [CV 1/3] END max_depth=10, max_features=7, min_samples_leaf=11;, score=0.834 total time=   1.7s
# [CV 2/3] END max_depth=10, max_features=7, min_samples_leaf=11;, score=0.837 total time=   1.7s
# [CV 3/3] END max_depth=10, max_features=7, min_samples_leaf=11;, score=0.828 total time=   1.8s
# [CV 1/3] END max_depth=15, max_features=4, min_samples_leaf=3;, score=0.829 total time=   1.7s
# [CV 2/3] END max_depth=15, max_features=4, min_samples_leaf=3;, score=0.836 total time=   1.7s
# [CV 3/3] END max_depth=15, max_features=4, min_samples_leaf=3;, score=0.829 total time=   1.7s
# [CV 1/3] END max_depth=15, max_features=4, min_samples_leaf=5;, score=0.828 total time=   1.7s
# [CV 2/3] END max_depth=15, max_features=4, min_samples_leaf=5;, score=0.834 total time=   1.6s
# [CV 3/3] END max_depth=15, max_features=4, min_samples_leaf=5;, score=0.829 total time=   1.7s
# [CV 1/3] END max_depth=15, max_features=4, min_samples_leaf=7;, score=0.828 total time=   1.6s
# [CV 2/3] END max_depth=15, max_features=4, min_samples_leaf=7;, score=0.832 total time=   1.6s
# [CV 3/3] END max_depth=15, max_features=4, min_samples_leaf=7;, score=0.827 total time=   1.6s
# [CV 1/3] END max_depth=15, max_features=4, min_samples_leaf=9;, score=0.825 total time=   1.6s
# [CV 2/3] END max_depth=15, max_features=4, min_samples_leaf=9;, score=0.832 total time=   1.6s
# [CV 3/3] END max_depth=15, max_features=4, min_samples_leaf=9;, score=0.824 total time=   1.6s
# [CV 1/3] END max_depth=15, max_features=4, min_samples_leaf=11;, score=0.826 total time=   1.5s
# [CV 2/3] END max_depth=15, max_features=4, min_samples_leaf=11;, score=0.831 total time=   1.5s
# [CV 3/3] END max_depth=15, max_features=4, min_samples_leaf=11;, score=0.824 total time=   1.5s
# [CV 1/3] END max_depth=15, max_features=5, min_samples_leaf=3;, score=0.832 total time=   1.9s
# [CV 2/3] END max_depth=15, max_features=5, min_samples_leaf=3;, score=0.843 total time=   2.0s
# [CV 3/3] END max_depth=15, max_features=5, min_samples_leaf=3;, score=0.833 total time=   2.0s
# [CV 1/3] END max_depth=15, max_features=5, min_samples_leaf=5;, score=0.835 total time=   2.0s
# [CV 2/3] END max_depth=15, max_features=5, min_samples_leaf=5;, score=0.843 total time=   2.0s
# [CV 3/3] END max_depth=15, max_features=5, min_samples_leaf=5;, score=0.834 total time=   1.9s
# [CV 1/3] END max_depth=15, max_features=5, min_samples_leaf=7;, score=0.834 total time=   1.9s
# [CV 2/3] END max_depth=15, max_features=5, min_samples_leaf=7;, score=0.839 total time=   1.9s
# [CV 3/3] END max_depth=15, max_features=5, min_samples_leaf=7;, score=0.830 total time=   1.9s
# [CV 1/3] END max_depth=15, max_features=5, min_samples_leaf=9;, score=0.832 total time=   1.8s
# [CV 2/3] END max_depth=15, max_features=5, min_samples_leaf=9;, score=0.838 total time=   1.8s
# [CV 3/3] END max_depth=15, max_features=5, min_samples_leaf=9;, score=0.831 total time=   1.8s
# [CV 1/3] END max_depth=15, max_features=5, min_samples_leaf=11;, score=0.834 total time=   1.8s
# [CV 2/3] END max_depth=15, max_features=5, min_samples_leaf=11;, score=0.838 total time=   1.8s
# [CV 3/3] END max_depth=15, max_features=5, min_samples_leaf=11;, score=0.831 total time=   1.8s
# [CV 1/3] END max_depth=15, max_features=6, min_samples_leaf=3;, score=0.841 total time=   2.3s
# [CV 2/3] END max_depth=15, max_features=6, min_samples_leaf=3;, score=0.847 total time=   2.2s
# [CV 3/3] END max_depth=15, max_features=6, min_samples_leaf=3;, score=0.840 total time=   2.3s
# [CV 1/3] END max_depth=15, max_features=6, min_samples_leaf=5;, score=0.842 total time=   2.2s
# [CV 2/3] END max_depth=15, max_features=6, min_samples_leaf=5;, score=0.847 total time=   2.2s
# [CV 3/3] END max_depth=15, max_features=6, min_samples_leaf=5;, score=0.839 total time=   2.2s
# [CV 1/3] END max_depth=15, max_features=6, min_samples_leaf=7;, score=0.842 total time=   2.1s
# [CV 2/3] END max_depth=15, max_features=6, min_samples_leaf=7;, score=0.845 total time=   2.1s
# [CV 3/3] END max_depth=15, max_features=6, min_samples_leaf=7;, score=0.841 total time=   2.1s
# [CV 1/3] END max_depth=15, max_features=6, min_samples_leaf=9;, score=0.840 total time=   2.1s
# [CV 2/3] END max_depth=15, max_features=6, min_samples_leaf=9;, score=0.845 total time=   2.1s
# [CV 3/3] END max_depth=15, max_features=6, min_samples_leaf=9;, score=0.837 total time=   2.1s
# [CV 1/3] END max_depth=15, max_features=6, min_samples_leaf=11;, score=0.840 total time=   2.1s
# [CV 2/3] END max_depth=15, max_features=6, min_samples_leaf=11;, score=0.846 total time=   2.2s
# [CV 3/3] END max_depth=15, max_features=6, min_samples_leaf=11;, score=0.838 total time=   2.1s
# [CV 1/3] END max_depth=15, max_features=7, min_samples_leaf=3;, score=0.845 total time=   2.5s
# [CV 2/3] END max_depth=15, max_features=7, min_samples_leaf=3;, score=0.850 total time=   2.5s
# [CV 3/3] END max_depth=15, max_features=7, min_samples_leaf=3;, score=0.845 total time=   2.5s
# [CV 1/3] END max_depth=15, max_features=7, min_samples_leaf=5;, score=0.844 total time=   2.5s
# [CV 2/3] END max_depth=15, max_features=7, min_samples_leaf=5;, score=0.849 total time=   2.5s
# [CV 3/3] END max_depth=15, max_features=7, min_samples_leaf=5;, score=0.844 total time=   2.5s
# [CV 1/3] END max_depth=15, max_features=7, min_samples_leaf=7;, score=0.842 total time=   2.5s
# [CV 2/3] END max_depth=15, max_features=7, min_samples_leaf=7;, score=0.850 total time=   2.5s
# [CV 3/3] END max_depth=15, max_features=7, min_samples_leaf=7;, score=0.841 total time=   2.4s
# [CV 1/3] END max_depth=15, max_features=7, min_samples_leaf=9;, score=0.842 total time=   2.4s
# [CV 2/3] END max_depth=15, max_features=7, min_samples_leaf=9;, score=0.848 total time=   2.4s
# [CV 3/3] END max_depth=15, max_features=7, min_samples_leaf=9;, score=0.841 total time=   2.4s
# [CV 1/3] END max_depth=15, max_features=7, min_samples_leaf=11;, score=0.840 total time=   2.3s
# [CV 2/3] END max_depth=15, max_features=7, min_samples_leaf=11;, score=0.847 total time=   2.3s
# [CV 3/3] END max_depth=15, max_features=7, min_samples_leaf=11;, score=0.840 total time=   2.4s
# {'max_depth': 15, 'max_features': 7, 'min_samples_leaf': 3}

# %%
clf = RandomForestClassifier(n_estimators = 100, max_depth=15, max_features=7, min_samples_leaf=3, random_state=31)
clf.fit(X_train, y_train)
preds_train = clf.predict(X_train)
preds_test = clf.predict(X_test)
print(round(roc_auc_score(y_test, preds_test), 2))
# Out:
# 0.7

# %%
# Задание 4.12

feature_names = [x for x in df_dummies if x != 'RainTomorrow']
pd.DataFrame({'feat': feature_names,
              'coef': clf.feature_importances_}).sort_values(by='coef', ascending=False)
# Out:
#                    feat      coef
# 7           Humidity3pm  0.250783
# 2              Rainfall  0.079757
# 6           Humidity9am  0.070403
# 10             Cloud9am  0.067092
# 9           Pressure3pm  0.065272
# ..                  ...       ...
# 50   Location_Newcastle  0.000000
# 62  Location_SalmonGums  0.000000
# 51        Location_Nhil  0.000000
# 52   Location_NorahHead  0.000000
# 40   Location_GoldCoast  0.000000
#
# [123 rows x 2 columns]

# %% [markdown]
# # <center>Бустинг</center>

# %% [markdown]
# ![image.png](https://lms-cdn.skillfactory.ru/assets/courseware/v1/86ec44dadb1105d1e0717764b7e9d2a9/asset-v1:Skillfactory+DSMED+2023+type@asset+block/MATHML_md9_5_1.png)

# %% [markdown]
# * В **бэггинге** все модели обучаются одновременно, независимо и параллельно. В качестве итогового предсказания берётся усреднённый ответ (в задаче регрессии) или делается прогноз по большинству голосов (в задаче классификации).
#
# * В **бустинге** все модели обучаются поочерёдно, причём каждая последующая старается исправить ошибки, совершённые предыдущими.

# %% [markdown]
# ## <center>AdaBoost (Adaptive Boosting)</center>

# %% [markdown]
# **Бустинг** позволяет из большого количества относительно слабых и простых моделей получить одну сильную. В нашем случае будут рассматриваться деревья решений ограниченной глубины (всего из одного уровня) — их ещё называют **пнями**.

# %% [markdown]
# Пропишем сам алгоритм:
#
# Инициализируем веса объектов:
#
# $$w_{j}=\frac{1}{N}, j=1,2, \ldots, N$$
#
# Для всех $i$ от 1 до $K$ (если у нас $K$ базовых моделей):
#
# 2.1. Строим классификатор $a_i(x)$, используя веса $w_j$.
#
# 2.2. Вычисляем ошибку:
#
# $$\operatorname{err}_{i}=\sum_{j=1}^{N} w_{j}\left[y_{j} \neq a_{i}\left(x_{j}\right)\right]$$
#
# 2.3. Вычисляем вес нового алгоритма:
#
# $$c_{i}=\frac{1}{2} \ln \frac{1-e r r_{i}}{e r r_{i}}$$
#
# 2.4. Получаем новые веса объектов (классы определяются как -1 и +1):
#
# $$w_{j} \leftarrow w_{j} \cdot \exp \left(c_{i}\left[y_{j} \neq a_{i}\left(x_{j}\right)\right]\right), j=1, \ldots, N$$
#
# 2.5. Нормируем веса объектов:
#
# $$w_{j} \longleftarrow \frac{w_{j}}{\sum_{j=1}^{N} w_{j}}$$
#
# Группируем полученные модели:
#
# $$f_{K}(x)=\operatorname{sign}\left[\sum_{i=1}^{K} c_{i} a_{i}(x)\right]$$

# %% [markdown]
# > **$sign$** — это функция знака, которая извлекает знак действительного числа. Определяется следующим образом:
#
# $$\operatorname{sign}(x)=\left\{\begin{aligned} 1, & x>0 \\ 0, & x=0 \\-1, & x<0 \end{aligned}\right.$$

# %% [markdown]
# > Объект, который был классифицирован неправильно, имеет вес, более чем в два раза превышающий вес других объектов. Это означает, что он с большей вероятностью будет выбран несколько раз, и, таким образом, следующий пень будет больше сосредоточен на правильной классификации неправильно классифицированного образца. В этом и состоит идея *AdaBoost*.

# %% [markdown]
# ## <center>Градиентный бустинг</center>

# %% [markdown]
# > Принцип его работы аналогичен *AdaBoost*: следующие модели улучшают композицию построенных ранее.

# %% [markdown]
# Инициализируем композицию *GBM (Gradient Boosting Machine)* — $f(x) = a_0 (x)$, то есть добавляем первый базовый алгоритм. Например, можно использовать:
#
# * алгоритм $a_0 (x) = 0$, который всегда возвращает 0 (в задаче регрессии);
#
# * более сложный алгоритм $a_0 (x) = \frac{1}{N} \sum_{j=1}^N y_i$, который возвращает средний истинный ответ по всем элементам обучающей выборки (в задаче регрессии);
#
# * алгоритм $a_0 (x) = arg \ max_{y \in Y} \sum_{j=1}^N \left [y_i = y  \right ]$, который всегда возвращает метку самого распространённого класса в обучающей выборке (в задаче классификации).

# %% [markdown]
# Итеративно повторяем следующие три шага:
#
# 2.1. Вычисляем вектор сдвига:
#
# $$s=-\nabla F=\left[\begin{array}{c}-L_{\hat{y}}^{\prime}\left(y_{1}, a_{K-1}\left(x_{1}\right)\right) \\ -L_{\hat{y}}^{\prime}\left(y_{2}, a_{K-1}\left(x_{2}\right)\right) \\ \vdots \\ -L_{\hat{y}}^{\prime}\left(y_{N}, a_{K-1}\left(x_{N}\right)\right)\end{array}\right]$$
#
# 2.2. Строим очередной базовый алгоритм $a_K (x)$, который предсказывает вектор-сдвиг:
#
# $$a_{K}(x)=\arg \min _{a} \frac{1}{N} \sum_{j=1}^{N}\left(a\left(x_{j}\right)-s_{j}\right)^{2}$$
#
# 2.3. Добавляем $a_K (x)$ в композицию:
#
# $$a_{K}(x)=\sum_{i=1}^{K} a_{i}(x)$$
#
# Если выполнен критерий остановки, останавливаем итеративный процесс.

# %% [markdown]
# ## <center>XGBoost и CatBoost</center>

# %% [markdown]
# **XGBoost** — одна из самых эффективных реализаций алгоритма *Gradient Boosted Trees*. Название *XGBoost* расшифровывается  как eXtreme Gradient Boosting. *XGBoost* — это улучшение *GBM* через системную оптимизацию и усовершенствование алгоритма.

# %% [markdown]
# **CatBoost** — это библиотека градиентного бустинга, созданная Яндексом. Её особенность заключается в том, что в ней используются так называемые небрежные (oblivious) деревья решений, чтобы «вырастить» сбалансированное дерево.
#
# > Одно из **главных преимуществ** *CatBoost* заключается в том, что его можно использовать для данных, где категориальные признаки заранее не были преобразованы.

# %%
df = pd.read_csv('data/AirPass.csv')
df.head()
# Out:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  2  ...                       1
# 2                                  2  ...                       5
# 3                                  5  ...                       2
# 4                                  3  ...                       3
#
#    On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                 4                 3                 4                4
# 1                 1                 5                 3                1
# 2                 4                 3                 4                4
# 3                 2                 5                 3                1
# 4                 3                 4                 4                3
#
#    Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0                 5            5                          25
# 1                 4            1                           1
# 2                 4            5                           0
# 3                 4            2                          11
# 4                 3            3                           0
#
#    Arrival Delay in Minutes             satisfaction
# 0                      18.0  neutral or dissatisfied
# 1                       6.0  neutral or dissatisfied
# 2                       0.0                satisfied
# 3                       9.0  neutral or dissatisfied
# 4                       0.0                satisfied
#
# [5 rows x 25 columns]

# %%
df = df.drop('Unnamed: 0', axis = 1)
df.head()
# Out:
#        id  Gender      Customer Type  Age   Type of Travel     Class  \
# 0   70172    Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1    5047    Male  disloyal Customer   25  Business travel  Business
# 2  110028  Female     Loyal Customer   26  Business travel  Business
# 3   24026  Female     Loyal Customer   25  Business travel  Business
# 4  119299    Male     Loyal Customer   61  Business travel  Business
#
#    Flight Distance  Inflight wifi service  Departure/Arrival time convenient  \
# 0              460                      3                                  4
# 1              235                      3                                  2
# 2             1142                      2                                  2
# 3              562                      2                                  5
# 4              214                      3                                  3
#
#    Ease of Online booking  ...  Inflight entertainment  On-board service  \
# 0                       3  ...                       5                 4
# 1                       3  ...                       1                 1
# 2                       2  ...                       5                 4
# 3                       5  ...                       2                 2
# 4                       3  ...                       3                 3
#
#    Leg room service  Baggage handling  Checkin service  Inflight service  \
# 0                 3                 4                4                 5
# 1                 5                 3                1                 4
# 2                 3                 4                4                 4
# 3                 5                 3                1                 4
# 4                 4                 4                3                 3
#
#    Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes  \
# 0            5                          25                      18.0
# 1            1                           1                       6.0
# 2            5                           0                       0.0
# 3            2                          11                       9.0
# 4            3                           0                       0.0
#
#               satisfaction
# 0  neutral or dissatisfied
# 1  neutral or dissatisfied
# 2                satisfied
# 3  neutral or dissatisfied
# 4                satisfied
#
# [5 rows x 24 columns]

# %%
# Задание 6.1

df.isnull().sum().sum()
# Out:
# 310

# %%
# Задание 6.2

df['Arrival Delay in Minutes'] = df['Arrival Delay in Minutes'].fillna(df['Arrival Delay in Minutes'].median())
round(df['Arrival Delay in Minutes'].mean(), 2)
# Out:
# 15.13

# %%
# Задание 6.3

# 1.

df.groupby('Gender')['satisfaction'].value_counts()*100/df.shape[0]
# Out:
# Gender  satisfaction
# Female  neutral or dissatisfied    29.058554
#         satisfied                  21.687327
# Male    neutral or dissatisfied    27.608177
#         satisfied                  21.645942
# Name: count, dtype: float64

# %%
# 2.

df.groupby('Type of Travel')['satisfaction'].value_counts()*100/df.shape[0]
# Out:
# Type of Travel   satisfaction
# Business travel  satisfied                  40.177472
#                  neutral or dissatisfied    28.785225
# Personal Travel  neutral or dissatisfied    27.881506
#                  satisfied                   3.155798
# Name: count, dtype: float64

# %%
# 3.

df.groupby('Class')['satisfaction'].value_counts()*100/df.shape[0]
# Out:
# Class     satisfaction
# Business  satisfied                  33.184478
#           neutral or dissatisfied    14.614452
# Eco       neutral or dissatisfied    36.614567
#           satisfied                   8.374076
# Eco Plus  neutral or dissatisfied     5.437712
#           satisfied                   1.774715
# Name: count, dtype: float64

# %%
# Перекодируем часть бинарных признаков, чтобы использовать их при обучении
df['satisfaction'] = df['satisfaction'].map({'neutral or dissatisfied':0 , 'satisfied':1})
df['Customer Type'] = df['Customer Type'].map({'Loyal Customer':1, 'disloyal Customer':0})
df['Type of Travel'] = df['Type of Travel'].map({'Personal Travel':0, 'Business travel':1})
df['Gender'] = df['Gender'].map({'Male': 0, 'Female': 1})

# %%
# Задание 6.4

df=pd.get_dummies(df)
df.shape
# Out:
# (103904, 26)

# %%
# Задание 6.5

X = df.drop('satisfaction', axis = 1)
y = df['satisfaction']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=26)
y_test.shape
# Out:
# (20781,)

# %%
# Задание 6.6

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X_train) 
X_train = scaler.transform(X_train) 
X_test = scaler.transform(X_test) 
X_test[0][0]
# Out:
# 0.9408251379303

# %%
# Задание 6.7

model_lr = LogisticRegression()
model_lr.fit(X_train, y_train)
preds_test = model_lr.predict(X_test)
f1_score(preds_test, y_test)
# Out:
# 0.8547046934650797

# %%
# Задание 6.8

from sklearn.ensemble import AdaBoostClassifier

model_ada = AdaBoostClassifier(DecisionTreeClassifier(random_state=26),random_state=26,learning_rate=0.01)

model_ada.fit(X_train, y_train)
preds_test = model_ada.predict(X_test)
f1_score(preds_test, y_test)
# Out:
# c:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# 0.9404794558121674

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Задание 6.9

from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import make_scorer

params = {"n_estimators":2**np.arange(8), "learning_rate":0.1**np.arange(3)}

model_for_gs = GradientBoostingClassifier()
params = {"n_estimators":2**np.arange(8), "learning_rate":0.1**np.arange(3)}
gs = GridSearchCV(model_for_gs, 
                  params, 
                  cv=3, 
                  scoring=make_scorer(f1_score),
                  verbose=5)
 
gs.fit(X_train, y_train)
 
print("Лучшие гиперпараметры:", gs.best_params_)
print("Лучшее значение метрики:", gs.best_score_)
# Out:
# Fitting 3 folds for each of 24 candidates, totalling 72 fits
# [CV 1/3] END .learning_rate=1.0, n_estimators=1;, score=0.873 total time=   0.0s
# [CV 2/3] END .learning_rate=1.0, n_estimators=1;, score=0.870 total time=   0.0s
# [CV 3/3] END .learning_rate=1.0, n_estimators=1;, score=0.871 total time=   0.0s
# [CV 1/3] END .learning_rate=1.0, n_estimators=2;, score=0.880 total time=   0.1s
# [CV 2/3] END .learning_rate=1.0, n_estimators=2;, score=0.878 total time=   0.1s
# [CV 3/3] END .learning_rate=1.0, n_estimators=2;, score=0.875 total time=   0.1s
# [CV 1/3] END .learning_rate=1.0, n_estimators=4;, score=0.901 total time=   0.3s
# [CV 2/3] END .learning_rate=1.0, n_estimators=4;, score=0.896 total time=   0.3s
# [CV 3/3] END .learning_rate=1.0, n_estimators=4;, score=0.897 total time=   0.3s
# [CV 1/3] END .learning_rate=1.0, n_estimators=8;, score=0.920 total time=   0.6s
# [CV 2/3] END .learning_rate=1.0, n_estimators=8;, score=0.920 total time=   0.7s
# [CV 3/3] END .learning_rate=1.0, n_estimators=8;, score=0.919 total time=   0.9s
# [CV 1/3] END learning_rate=1.0, n_estimators=16;, score=0.935 total time=   1.3s
# [CV 2/3] END learning_rate=1.0, n_estimators=16;, score=0.938 total time=   1.4s
# [CV 3/3] END learning_rate=1.0, n_estimators=16;, score=0.933 total time=   1.3s
# [CV 1/3] END learning_rate=1.0, n_estimators=32;, score=0.943 total time=   2.7s
# [CV 2/3] END learning_rate=1.0, n_estimators=32;, score=0.945 total time=   2.7s
# [CV 3/3] END learning_rate=1.0, n_estimators=32;, score=0.944 total time=   2.7s
# [CV 1/3] END learning_rate=1.0, n_estimators=64;, score=0.947 total time=   5.6s
# [CV 2/3] END learning_rate=1.0, n_estimators=64;, score=0.947 total time=   5.5s
# [CV 3/3] END learning_rate=1.0, n_estimators=64;, score=0.948 total time=   5.3s
# [CV 1/3] END learning_rate=1.0, n_estimators=128;, score=0.949 total time=  10.9s
# [CV 2/3] END learning_rate=1.0, n_estimators=128;, score=0.949 total time=  11.3s
# [CV 3/3] END learning_rate=1.0, n_estimators=128;, score=0.949 total time=  10.4s
# [CV 1/3] END .learning_rate=0.1, n_estimators=1;, score=0.000 total time=   0.0s
# [CV 2/3] END .learning_rate=0.1, n_estimators=1;, score=0.000 total time=   0.0s
# [CV 3/3] END .learning_rate=0.1, n_estimators=1;, score=0.000 total time=   0.0s
# [CV 1/3] END .learning_rate=0.1, n_estimators=2;, score=0.765 total time=   0.1s
# [CV 2/3] END .learning_rate=0.1, n_estimators=2;, score=0.802 total time=   0.1s
# [CV 3/3] END .learning_rate=0.1, n_estimators=2;, score=0.794 total time=   0.1s
# [CV 1/3] END .learning_rate=0.1, n_estimators=4;, score=0.880 total time=   0.3s
# [CV 2/3] END .learning_rate=0.1, n_estimators=4;, score=0.880 total time=   0.3s
# [CV 3/3] END .learning_rate=0.1, n_estimators=4;, score=0.878 total time=   0.3s
# [CV 1/3] END .learning_rate=0.1, n_estimators=8;, score=0.881 total time=   0.6s
# [CV 2/3] END .learning_rate=0.1, n_estimators=8;, score=0.878 total time=   0.6s
# [CV 3/3] END .learning_rate=0.1, n_estimators=8;, score=0.881 total time=   0.6s
# [CV 1/3] END learning_rate=0.1, n_estimators=16;, score=0.886 total time=   1.3s
# [CV 2/3] END learning_rate=0.1, n_estimators=16;, score=0.887 total time=   1.4s
# [CV 3/3] END learning_rate=0.1, n_estimators=16;, score=0.889 total time=   1.5s
# [CV 1/3] END learning_rate=0.1, n_estimators=32;, score=0.914 total time=   2.9s
# [CV 2/3] END learning_rate=0.1, n_estimators=32;, score=0.919 total time=   2.5s
# [CV 3/3] END learning_rate=0.1, n_estimators=32;, score=0.910 total time=   2.5s
# [CV 1/3] END learning_rate=0.1, n_estimators=64;, score=0.928 total time=   5.1s
# [CV 2/3] END learning_rate=0.1, n_estimators=64;, score=0.929 total time=   5.1s
# [CV 3/3] END learning_rate=0.1, n_estimators=64;, score=0.929 total time=   5.4s
# [CV 1/3] END learning_rate=0.1, n_estimators=128;, score=0.939 total time=  10.9s
# [CV 2/3] END learning_rate=0.1, n_estimators=128;, score=0.938 total time=  10.3s
# [CV 3/3] END learning_rate=0.1, n_estimators=128;, score=0.938 total time=  11.2s
# [CV 1/3] END learning_rate=0.010000000000000002, n_estimators=1;, score=0.000 total time=   0.0s
# [CV 2/3] END learning_rate=0.010000000000000002, n_estimators=1;, score=0.000 total time=   0.0s
# [CV 3/3] END learning_rate=0.010000000000000002, n_estimators=1;, score=0.000 total time=   0.0s
# [CV 1/3] END learning_rate=0.010000000000000002, n_estimators=2;, score=0.000 total time=   0.1s
# [CV 2/3] END learning_rate=0.010000000000000002, n_estimators=2;, score=0.000 total time=   0.1s
# [CV 3/3] END learning_rate=0.010000000000000002, n_estimators=2;, score=0.000 total time=   0.1s
# [CV 1/3] END learning_rate=0.010000000000000002, n_estimators=4;, score=0.000 total time=   0.2s
# [CV 2/3] END learning_rate=0.010000000000000002, n_estimators=4;, score=0.000 total time=   0.2s
# [CV 3/3] END learning_rate=0.010000000000000002, n_estimators=4;, score=0.000 total time=   0.3s
# [CV 1/3] END learning_rate=0.010000000000000002, n_estimators=8;, score=0.000 total time=   0.6s
# [CV 2/3] END learning_rate=0.010000000000000002, n_estimators=8;, score=0.000 total time=   0.6s
# [CV 3/3] END learning_rate=0.010000000000000002, n_estimators=8;, score=0.000 total time=   0.6s
# [CV 1/3] END learning_rate=0.010000000000000002, n_estimators=16;, score=0.765 total time=   1.2s
# [CV 2/3] END learning_rate=0.010000000000000002, n_estimators=16;, score=0.802 total time=   1.2s
# [CV 3/3] END learning_rate=0.010000000000000002, n_estimators=16;, score=0.757 total time=   1.2s
# [CV 1/3] END learning_rate=0.010000000000000002, n_estimators=32;, score=0.878 total time=   2.5s
# [CV 2/3] END learning_rate=0.010000000000000002, n_estimators=32;, score=0.860 total time=   2.5s
# [CV 3/3] END learning_rate=0.010000000000000002, n_estimators=32;, score=0.858 total time=   2.5s
# [CV 1/3] END learning_rate=0.010000000000000002, n_estimators=64;, score=0.881 total time=   5.1s
# [CV 2/3] END learning_rate=0.010000000000000002, n_estimators=64;, score=0.877 total time=   5.1s
# [CV 3/3] END learning_rate=0.010000000000000002, n_estimators=64;, score=0.877 total time=   5.2s
# [CV 1/3] END learning_rate=0.010000000000000002, n_estimators=128;, score=0.886 total time=  10.7s
# [CV 2/3] END learning_rate=0.010000000000000002, n_estimators=128;, score=0.886 total time=  10.2s
# [CV 3/3] END learning_rate=0.010000000000000002, n_estimators=128;, score=0.885 total time=  10.2s
# Лучшие гиперпараметры: {'learning_rate': 1.0, 'n_estimators': 128}
# Лучшее значение метрики: 0.9491124369367409

# %%
# Задание 6.10

from xgboost import XGBClassifier

model_xgb = XGBClassifier(random_state=26)
model_xgb.fit(X_train,y_train)
preds_test = model_xgb.predict(X_test)
f1_score(preds_test, y_test)
# Out:
# 0.9573723114544546

# %%
# Задание 6.11

from catboost import CatBoostClassifier

model = CatBoostClassifier(random_state=26)
model.fit(X_train, y_train)
preds_class = model.predict(X_test)
f1_score(preds_class, y_test)
# Out:
# Learning rate set to 0.068023
# 0:	learn: 0.6018151	total: 108ms	remaining: 1m 48s
# 1:	learn: 0.5020758	total: 116ms	remaining: 58s
# 2:	learn: 0.4472471	total: 125ms	remaining: 41.5s
# 3:	learn: 0.4028689	total: 133ms	remaining: 33.2s
# 4:	learn: 0.3674734	total: 142ms	remaining: 28.2s
# 5:	learn: 0.3397847	total: 150ms	remaining: 24.8s
# 6:	learn: 0.3121211	total: 158ms	remaining: 22.3s
# 7:	learn: 0.2917500	total: 166ms	remaining: 20.6s
# 8:	learn: 0.2749040	total: 174ms	remaining: 19.2s
# 9:	learn: 0.2575190	total: 182ms	remaining: 18s
# 10:	learn: 0.2473691	total: 190ms	remaining: 17.1s
# 11:	learn: 0.2377533	total: 198ms	remaining: 16.3s
# 12:	learn: 0.2279311	total: 206ms	remaining: 15.7s
# 13:	learn: 0.2212511	total: 215ms	remaining: 15.2s
# 14:	learn: 0.2100357	total: 225ms	remaining: 14.7s
# 15:	learn: 0.2025732	total: 234ms	remaining: 14.4s
# 16:	learn: 0.1942300	total: 242ms	remaining: 14s
# 17:	learn: 0.1877937	total: 251ms	remaining: 13.7s
# 18:	learn: 0.1832380	total: 259ms	remaining: 13.4s
# 19:	learn: 0.1797365	total: 266ms	remaining: 13.1s
# 20:	learn: 0.1766269	total: 275ms	remaining: 12.8s
# 21:	learn: 0.1724834	total: 283ms	remaining: 12.6s
# 22:	learn: 0.1681075	total: 292ms	remaining: 12.4s
# 23:	learn: 0.1659677	total: 299ms	remaining: 12.2s
# 24:	learn: 0.1636305	total: 307ms	remaining: 12s
# 25:	learn: 0.1615297	total: 315ms	remaining: 11.8s
# 26:	learn: 0.1591233	total: 323ms	remaining: 11.6s
# 27:	learn: 0.1572188	total: 331ms	remaining: 11.5s
# 28:	learn: 0.1557161	total: 338ms	remaining: 11.3s
# 29:	learn: 0.1541993	total: 346ms	remaining: 11.2s
# 30:	learn: 0.1527117	total: 355ms	remaining: 11.1s
# 31:	learn: 0.1511750	total: 364ms	remaining: 11s
# 32:	learn: 0.1495155	total: 372ms	remaining: 10.9s
# 33:	learn: 0.1482199	total: 381ms	remaining: 10.8s
# 34:	learn: 0.1447922	total: 389ms	remaining: 10.7s
# 35:	learn: 0.1437618	total: 397ms	remaining: 10.6s
# 36:	learn: 0.1428307	total: 406ms	remaining: 10.6s
# 37:	learn: 0.1418335	total: 414ms	remaining: 10.5s
# 38:	learn: 0.1405886	total: 424ms	remaining: 10.4s
# 39:	learn: 0.1393059	total: 432ms	remaining: 10.4s
# 40:	learn: 0.1385384	total: 440ms	remaining: 10.3s
# 41:	learn: 0.1375509	total: 448ms	remaining: 10.2s
# 42:	learn: 0.1359835	total: 456ms	remaining: 10.1s
# 43:	learn: 0.1347066	total: 463ms	remaining: 10.1s
# 44:	learn: 0.1327071	total: 471ms	remaining: 9.99s
# 45:	learn: 0.1316580	total: 479ms	remaining: 9.94s
# 46:	learn: 0.1304422	total: 488ms	remaining: 9.89s
# 47:	learn: 0.1299835	total: 495ms	remaining: 9.82s
# 48:	learn: 0.1295420	total: 503ms	remaining: 9.76s
# 49:	learn: 0.1290790	total: 512ms	remaining: 9.72s
# 50:	learn: 0.1285284	total: 521ms	remaining: 9.69s
# 51:	learn: 0.1280241	total: 530ms	remaining: 9.67s
# 52:	learn: 0.1272417	total: 538ms	remaining: 9.6s
# 53:	learn: 0.1265525	total: 546ms	remaining: 9.57s
# 54:	learn: 0.1258799	total: 554ms	remaining: 9.52s
# 55:	learn: 0.1248607	total: 562ms	remaining: 9.47s
# 56:	learn: 0.1242196	total: 571ms	remaining: 9.44s
# 57:	learn: 0.1240464	total: 579ms	remaining: 9.4s
# 58:	learn: 0.1227505	total: 588ms	remaining: 9.38s
# 59:	learn: 0.1219310	total: 596ms	remaining: 9.34s
# 60:	learn: 0.1214669	total: 605ms	remaining: 9.3s
# 61:	learn: 0.1209629	total: 613ms	remaining: 9.28s
# 62:	learn: 0.1204270	total: 623ms	remaining: 9.26s
# 63:	learn: 0.1197951	total: 630ms	remaining: 9.22s
# 64:	learn: 0.1188689	total: 638ms	remaining: 9.18s
# 65:	learn: 0.1179641	total: 646ms	remaining: 9.14s
# 66:	learn: 0.1175382	total: 655ms	remaining: 9.12s
# 67:	learn: 0.1170936	total: 663ms	remaining: 9.08s
# 68:	learn: 0.1167482	total: 670ms	remaining: 9.04s
# 69:	learn: 0.1164256	total: 678ms	remaining: 9.01s
# 70:	learn: 0.1161022	total: 686ms	remaining: 8.98s
# 71:	learn: 0.1154266	total: 694ms	remaining: 8.94s
# 72:	learn: 0.1143862	total: 703ms	remaining: 8.92s
# 73:	learn: 0.1141025	total: 711ms	remaining: 8.89s
# 74:	learn: 0.1138525	total: 720ms	remaining: 8.88s
# 75:	learn: 0.1134943	total: 728ms	remaining: 8.85s
# 76:	learn: 0.1132630	total: 736ms	remaining: 8.82s
# 77:	learn: 0.1129337	total: 743ms	remaining: 8.79s
# 78:	learn: 0.1123692	total: 751ms	remaining: 8.75s
# 79:	learn: 0.1120446	total: 759ms	remaining: 8.73s
# 80:	learn: 0.1117098	total: 766ms	remaining: 8.69s
# 81:	learn: 0.1108358	total: 775ms	remaining: 8.67s
# 82:	learn: 0.1102779	total: 784ms	remaining: 8.66s
# 83:	learn: 0.1099572	total: 792ms	remaining: 8.63s
# 84:	learn: 0.1098577	total: 801ms	remaining: 8.62s
# 85:	learn: 0.1092686	total: 810ms	remaining: 8.61s
# 86:	learn: 0.1090127	total: 818ms	remaining: 8.59s
# 87:	learn: 0.1087985	total: 827ms	remaining: 8.57s
# 88:	learn: 0.1081520	total: 837ms	remaining: 8.56s
# 89:	learn: 0.1079692	total: 845ms	remaining: 8.54s
# 90:	learn: 0.1077513	total: 854ms	remaining: 8.53s
# 91:	learn: 0.1075283	total: 863ms	remaining: 8.52s
# 92:	learn: 0.1071405	total: 872ms	remaining: 8.5s
# 93:	learn: 0.1070247	total: 882ms	remaining: 8.5s
# 94:	learn: 0.1068191	total: 890ms	remaining: 8.48s
# 95:	learn: 0.1064461	total: 897ms	remaining: 8.45s
# 96:	learn: 0.1059301	total: 905ms	remaining: 8.43s
# 97:	learn: 0.1056716	total: 915ms	remaining: 8.42s
# 98:	learn: 0.1054190	total: 924ms	remaining: 8.4s
# 99:	learn: 0.1051352	total: 933ms	remaining: 8.4s
# 100:	learn: 0.1047668	total: 942ms	remaining: 8.38s
# 101:	learn: 0.1044767	total: 950ms	remaining: 8.36s
# 102:	learn: 0.1041726	total: 960ms	remaining: 8.36s
# 103:	learn: 0.1039212	total: 969ms	remaining: 8.35s
# 104:	learn: 0.1034243	total: 978ms	remaining: 8.34s
# 105:	learn: 0.1032076	total: 987ms	remaining: 8.32s
# 106:	learn: 0.1030340	total: 996ms	remaining: 8.32s
# 107:	learn: 0.1025610	total: 1s	remaining: 8.3s
# 108:	learn: 0.1022939	total: 1.01s	remaining: 8.3s
# 109:	learn: 0.1021190	total: 1.03s	remaining: 8.3s
# 110:	learn: 0.1017958	total: 1.03s	remaining: 8.29s
# 111:	learn: 0.1015855	total: 1.04s	remaining: 8.29s
# 112:	learn: 0.1011751	total: 1.05s	remaining: 8.28s
# 113:	learn: 0.1008758	total: 1.06s	remaining: 8.27s
# 114:	learn: 0.1006959	total: 1.07s	remaining: 8.27s
# 115:	learn: 0.1005648	total: 1.08s	remaining: 8.25s
# 116:	learn: 0.1003042	total: 1.09s	remaining: 8.24s
# 117:	learn: 0.1000929	total: 1.1s	remaining: 8.24s
# 118:	learn: 0.0999172	total: 1.11s	remaining: 8.24s
# 119:	learn: 0.0995889	total: 1.12s	remaining: 8.23s
# 120:	learn: 0.0992165	total: 1.13s	remaining: 8.21s
# 121:	learn: 0.0991356	total: 1.14s	remaining: 8.22s
# 122:	learn: 0.0990490	total: 1.15s	remaining: 8.22s
# 123:	learn: 0.0988976	total: 1.16s	remaining: 8.2s
# 124:	learn: 0.0987813	total: 1.17s	remaining: 8.19s
# 125:	learn: 0.0982176	total: 1.18s	remaining: 8.18s
# 126:	learn: 0.0979958	total: 1.19s	remaining: 8.18s
# 127:	learn: 0.0975457	total: 1.2s	remaining: 8.17s
# 128:	learn: 0.0973965	total: 1.21s	remaining: 8.16s
# 129:	learn: 0.0971497	total: 1.22s	remaining: 8.16s
# 130:	learn: 0.0969599	total: 1.23s	remaining: 8.15s
# 131:	learn: 0.0968170	total: 1.24s	remaining: 8.14s
# 132:	learn: 0.0966654	total: 1.25s	remaining: 8.13s
# 133:	learn: 0.0965934	total: 1.26s	remaining: 8.12s
# 134:	learn: 0.0965289	total: 1.27s	remaining: 8.12s
# 135:	learn: 0.0963292	total: 1.27s	remaining: 8.1s
# 136:	learn: 0.0962324	total: 1.28s	remaining: 8.08s
# 137:	learn: 0.0960270	total: 1.29s	remaining: 8.06s
# 138:	learn: 0.0957716	total: 1.3s	remaining: 8.05s
# 139:	learn: 0.0956517	total: 1.31s	remaining: 8.04s
# 140:	learn: 0.0954565	total: 1.32s	remaining: 8.03s
# 141:	learn: 0.0952810	total: 1.32s	remaining: 8.01s
# 142:	learn: 0.0951754	total: 1.33s	remaining: 7.99s
# 143:	learn: 0.0950736	total: 1.34s	remaining: 7.97s
# 144:	learn: 0.0948308	total: 1.35s	remaining: 7.96s
# 145:	learn: 0.0947879	total: 1.36s	remaining: 7.95s
# 146:	learn: 0.0942155	total: 1.37s	remaining: 7.94s
# 147:	learn: 0.0940961	total: 1.37s	remaining: 7.92s
# 148:	learn: 0.0939182	total: 1.38s	remaining: 7.9s
# 149:	learn: 0.0937727	total: 1.39s	remaining: 7.88s
# 150:	learn: 0.0936794	total: 1.4s	remaining: 7.87s
# 151:	learn: 0.0934161	total: 1.41s	remaining: 7.86s
# 152:	learn: 0.0930804	total: 1.42s	remaining: 7.84s
# 153:	learn: 0.0930079	total: 1.43s	remaining: 7.83s
# 154:	learn: 0.0928106	total: 1.44s	remaining: 7.82s
# 155:	learn: 0.0926320	total: 1.44s	remaining: 7.81s
# 156:	learn: 0.0924431	total: 1.45s	remaining: 7.8s
# 157:	learn: 0.0923595	total: 1.46s	remaining: 7.78s
# 158:	learn: 0.0922554	total: 1.47s	remaining: 7.77s
# 159:	learn: 0.0921874	total: 1.48s	remaining: 7.76s
# 160:	learn: 0.0920776	total: 1.49s	remaining: 7.75s
# 161:	learn: 0.0920000	total: 1.5s	remaining: 7.74s
# 162:	learn: 0.0918987	total: 1.5s	remaining: 7.72s
# 163:	learn: 0.0917727	total: 1.51s	remaining: 7.71s
# 164:	learn: 0.0916433	total: 1.52s	remaining: 7.7s
# 165:	learn: 0.0911486	total: 1.53s	remaining: 7.68s
# 166:	learn: 0.0909947	total: 1.54s	remaining: 7.67s
# 167:	learn: 0.0909358	total: 1.55s	remaining: 7.66s
# 168:	learn: 0.0908311	total: 1.56s	remaining: 7.65s
# 169:	learn: 0.0906577	total: 1.56s	remaining: 7.63s
# 170:	learn: 0.0905658	total: 1.57s	remaining: 7.62s
# 171:	learn: 0.0904869	total: 1.58s	remaining: 7.61s
# 172:	learn: 0.0903171	total: 1.59s	remaining: 7.6s
# 173:	learn: 0.0901361	total: 1.6s	remaining: 7.6s
# 174:	learn: 0.0900046	total: 1.61s	remaining: 7.59s
# 175:	learn: 0.0899255	total: 1.62s	remaining: 7.58s
# 176:	learn: 0.0898379	total: 1.63s	remaining: 7.57s
# 177:	learn: 0.0897781	total: 1.64s	remaining: 7.57s
# 178:	learn: 0.0895871	total: 1.65s	remaining: 7.56s
# 179:	learn: 0.0894744	total: 1.66s	remaining: 7.55s
# 180:	learn: 0.0894224	total: 1.67s	remaining: 7.55s
# 181:	learn: 0.0893369	total: 1.68s	remaining: 7.54s
# 182:	learn: 0.0892388	total: 1.69s	remaining: 7.53s
# 183:	learn: 0.0891403	total: 1.7s	remaining: 7.52s
# 184:	learn: 0.0890758	total: 1.71s	remaining: 7.51s
# 185:	learn: 0.0887365	total: 1.71s	remaining: 7.5s
# 186:	learn: 0.0886925	total: 1.72s	remaining: 7.5s
# 187:	learn: 0.0885184	total: 1.73s	remaining: 7.49s
# 188:	learn: 0.0880643	total: 1.74s	remaining: 7.48s
# 189:	learn: 0.0877916	total: 1.75s	remaining: 7.47s
# 190:	learn: 0.0875652	total: 1.76s	remaining: 7.47s
# 191:	learn: 0.0873675	total: 1.77s	remaining: 7.46s
# 192:	learn: 0.0872981	total: 1.78s	remaining: 7.44s
# 193:	learn: 0.0871525	total: 1.79s	remaining: 7.43s
# 194:	learn: 0.0870339	total: 1.8s	remaining: 7.42s
# 195:	learn: 0.0868101	total: 1.81s	remaining: 7.42s
# 196:	learn: 0.0867377	total: 1.82s	remaining: 7.4s
# 197:	learn: 0.0866166	total: 1.82s	remaining: 7.39s
# 198:	learn: 0.0864927	total: 1.83s	remaining: 7.38s
# 199:	learn: 0.0864061	total: 1.84s	remaining: 7.38s
# 200:	learn: 0.0863154	total: 1.85s	remaining: 7.37s
# 201:	learn: 0.0862565	total: 1.86s	remaining: 7.36s
# 202:	learn: 0.0861893	total: 1.87s	remaining: 7.35s
# 203:	learn: 0.0858519	total: 1.88s	remaining: 7.34s
# 204:	learn: 0.0857502	total: 1.89s	remaining: 7.33s
# 205:	learn: 0.0856750	total: 1.9s	remaining: 7.32s
# 206:	learn: 0.0855698	total: 1.91s	remaining: 7.31s
# 207:	learn: 0.0855253	total: 1.92s	remaining: 7.3s
# 208:	learn: 0.0853861	total: 1.93s	remaining: 7.29s
# 209:	learn: 0.0852943	total: 1.93s	remaining: 7.27s
# 210:	learn: 0.0851894	total: 1.94s	remaining: 7.26s
# 211:	learn: 0.0851451	total: 1.95s	remaining: 7.25s
# 212:	learn: 0.0850978	total: 1.96s	remaining: 7.25s
# 213:	learn: 0.0850196	total: 1.97s	remaining: 7.24s
# 214:	learn: 0.0849615	total: 1.98s	remaining: 7.23s
# 215:	learn: 0.0848995	total: 1.99s	remaining: 7.22s
# 216:	learn: 0.0848446	total: 2s	remaining: 7.21s
# 217:	learn: 0.0848059	total: 2.01s	remaining: 7.2s
# 218:	learn: 0.0847253	total: 2.02s	remaining: 7.2s
# 219:	learn: 0.0845712	total: 2.03s	remaining: 7.19s
# 220:	learn: 0.0844833	total: 2.04s	remaining: 7.18s
# 221:	learn: 0.0844594	total: 2.05s	remaining: 7.17s
# 222:	learn: 0.0844196	total: 2.06s	remaining: 7.17s
# 223:	learn: 0.0842787	total: 2.07s	remaining: 7.16s
# 224:	learn: 0.0841843	total: 2.08s	remaining: 7.16s
# 225:	learn: 0.0841121	total: 2.09s	remaining: 7.15s
# 226:	learn: 0.0840441	total: 2.1s	remaining: 7.14s
# 227:	learn: 0.0839354	total: 2.11s	remaining: 7.13s
# 228:	learn: 0.0837709	total: 2.12s	remaining: 7.12s
# 229:	learn: 0.0836366	total: 2.12s	remaining: 7.11s
# 230:	learn: 0.0835656	total: 2.13s	remaining: 7.1s
# 231:	learn: 0.0834631	total: 2.14s	remaining: 7.09s
# 232:	learn: 0.0833436	total: 2.15s	remaining: 7.08s
# 233:	learn: 0.0832525	total: 2.16s	remaining: 7.07s
# 234:	learn: 0.0832001	total: 2.17s	remaining: 7.06s
# 235:	learn: 0.0830116	total: 2.18s	remaining: 7.05s
# 236:	learn: 0.0829238	total: 2.19s	remaining: 7.04s
# 237:	learn: 0.0828486	total: 2.19s	remaining: 7.03s
# 238:	learn: 0.0827633	total: 2.2s	remaining: 7.02s
# 239:	learn: 0.0827321	total: 2.21s	remaining: 7.01s
# 240:	learn: 0.0826856	total: 2.22s	remaining: 7s
# 241:	learn: 0.0826182	total: 2.23s	remaining: 6.99s
# 242:	learn: 0.0824740	total: 2.24s	remaining: 6.98s
# 243:	learn: 0.0824252	total: 2.25s	remaining: 6.97s
# 244:	learn: 0.0823914	total: 2.26s	remaining: 6.96s
# 245:	learn: 0.0823617	total: 2.27s	remaining: 6.96s
# 246:	learn: 0.0823021	total: 2.28s	remaining: 6.95s
# 247:	learn: 0.0821613	total: 2.29s	remaining: 6.94s
# 248:	learn: 0.0820706	total: 2.3s	remaining: 6.93s
# 249:	learn: 0.0819199	total: 2.31s	remaining: 6.92s
# 250:	learn: 0.0818811	total: 2.31s	remaining: 6.91s
# 251:	learn: 0.0818266	total: 2.32s	remaining: 6.9s
# 252:	learn: 0.0817063	total: 2.33s	remaining: 6.88s
# 253:	learn: 0.0816097	total: 2.34s	remaining: 6.87s
# 254:	learn: 0.0815500	total: 2.35s	remaining: 6.86s
# 255:	learn: 0.0814762	total: 2.36s	remaining: 6.85s
# 256:	learn: 0.0814238	total: 2.37s	remaining: 6.84s
# 257:	learn: 0.0813821	total: 2.38s	remaining: 6.83s
# 258:	learn: 0.0813327	total: 2.39s	remaining: 6.83s
# 259:	learn: 0.0811305	total: 2.39s	remaining: 6.81s
# 260:	learn: 0.0810983	total: 2.4s	remaining: 6.8s
# 261:	learn: 0.0810765	total: 2.41s	remaining: 6.8s
# 262:	learn: 0.0810692	total: 2.42s	remaining: 6.79s
# 263:	learn: 0.0809733	total: 2.43s	remaining: 6.78s
# 264:	learn: 0.0809290	total: 2.44s	remaining: 6.77s
# 265:	learn: 0.0809107	total: 2.45s	remaining: 6.76s
# 266:	learn: 0.0808676	total: 2.46s	remaining: 6.75s
# 267:	learn: 0.0807784	total: 2.47s	remaining: 6.74s
# 268:	learn: 0.0807211	total: 2.48s	remaining: 6.73s
# 269:	learn: 0.0806806	total: 2.49s	remaining: 6.72s
# 270:	learn: 0.0805980	total: 2.49s	remaining: 6.71s
# 271:	learn: 0.0805311	total: 2.5s	remaining: 6.7s
# 272:	learn: 0.0804719	total: 2.51s	remaining: 6.69s
# 273:	learn: 0.0803349	total: 2.52s	remaining: 6.68s
# 274:	learn: 0.0802678	total: 2.54s	remaining: 6.7s
# 275:	learn: 0.0802328	total: 2.55s	remaining: 6.69s
# 276:	learn: 0.0801577	total: 2.56s	remaining: 6.68s
# 277:	learn: 0.0800718	total: 2.57s	remaining: 6.67s
# 278:	learn: 0.0799452	total: 2.58s	remaining: 6.66s
# 279:	learn: 0.0798961	total: 2.59s	remaining: 6.65s
# 280:	learn: 0.0798525	total: 2.6s	remaining: 6.64s
# 281:	learn: 0.0798148	total: 2.6s	remaining: 6.63s
# 282:	learn: 0.0797595	total: 2.61s	remaining: 6.62s
# 283:	learn: 0.0797325	total: 2.62s	remaining: 6.61s
# 284:	learn: 0.0797159	total: 2.63s	remaining: 6.6s
# 285:	learn: 0.0796057	total: 2.64s	remaining: 6.59s
# 286:	learn: 0.0795261	total: 2.65s	remaining: 6.58s
# 287:	learn: 0.0795025	total: 2.66s	remaining: 6.57s
# 288:	learn: 0.0794242	total: 2.67s	remaining: 6.56s
# 289:	learn: 0.0794091	total: 2.68s	remaining: 6.55s
# 290:	learn: 0.0793789	total: 2.68s	remaining: 6.54s
# 291:	learn: 0.0792930	total: 2.69s	remaining: 6.53s
# 292:	learn: 0.0792671	total: 2.7s	remaining: 6.52s
# 293:	learn: 0.0792277	total: 2.71s	remaining: 6.51s
# 294:	learn: 0.0791757	total: 2.72s	remaining: 6.5s
# 295:	learn: 0.0791407	total: 2.73s	remaining: 6.49s
# 296:	learn: 0.0790395	total: 2.74s	remaining: 6.48s
# 297:	learn: 0.0789943	total: 2.75s	remaining: 6.47s
# 298:	learn: 0.0789417	total: 2.76s	remaining: 6.46s
# 299:	learn: 0.0788920	total: 2.77s	remaining: 6.45s
# 300:	learn: 0.0788072	total: 2.77s	remaining: 6.44s
# 301:	learn: 0.0787068	total: 2.78s	remaining: 6.43s
# 302:	learn: 0.0786592	total: 2.79s	remaining: 6.42s
# 303:	learn: 0.0786297	total: 2.8s	remaining: 6.41s
# 304:	learn: 0.0785926	total: 2.81s	remaining: 6.4s
# 305:	learn: 0.0785667	total: 2.82s	remaining: 6.39s
# 306:	learn: 0.0785083	total: 2.83s	remaining: 6.38s
# 307:	learn: 0.0784612	total: 2.83s	remaining: 6.37s
# 308:	learn: 0.0784059	total: 2.84s	remaining: 6.36s
# 309:	learn: 0.0783769	total: 2.85s	remaining: 6.35s
# 310:	learn: 0.0783457	total: 2.86s	remaining: 6.34s
# 311:	learn: 0.0782539	total: 2.87s	remaining: 6.33s
# 312:	learn: 0.0782206	total: 2.88s	remaining: 6.32s
# 313:	learn: 0.0782020	total: 2.89s	remaining: 6.31s
# 314:	learn: 0.0781519	total: 2.9s	remaining: 6.3s
# 315:	learn: 0.0780599	total: 2.91s	remaining: 6.29s
# 316:	learn: 0.0780028	total: 2.91s	remaining: 6.28s
# 317:	learn: 0.0779841	total: 2.92s	remaining: 6.27s
# 318:	learn: 0.0779457	total: 2.93s	remaining: 6.26s
# 319:	learn: 0.0779231	total: 2.94s	remaining: 6.25s
# 320:	learn: 0.0778280	total: 2.95s	remaining: 6.24s
# 321:	learn: 0.0777676	total: 2.96s	remaining: 6.23s
# 322:	learn: 0.0777244	total: 2.97s	remaining: 6.22s
# 323:	learn: 0.0776901	total: 2.98s	remaining: 6.21s
# 324:	learn: 0.0776633	total: 2.98s	remaining: 6.2s
# 325:	learn: 0.0776141	total: 2.99s	remaining: 6.19s
# 326:	learn: 0.0775692	total: 3s	remaining: 6.18s
# 327:	learn: 0.0775169	total: 3.01s	remaining: 6.17s
# 328:	learn: 0.0774276	total: 3.02s	remaining: 6.16s
# 329:	learn: 0.0773924	total: 3.03s	remaining: 6.15s
# 330:	learn: 0.0773611	total: 3.04s	remaining: 6.13s
# 331:	learn: 0.0773509	total: 3.04s	remaining: 6.12s
# 332:	learn: 0.0772844	total: 3.05s	remaining: 6.11s
# 333:	learn: 0.0772448	total: 3.06s	remaining: 6.1s
# 334:	learn: 0.0772279	total: 3.07s	remaining: 6.09s
# 335:	learn: 0.0772144	total: 3.08s	remaining: 6.08s
# 336:	learn: 0.0771390	total: 3.09s	remaining: 6.07s
# 337:	learn: 0.0770933	total: 3.1s	remaining: 6.06s
# 338:	learn: 0.0770401	total: 3.1s	remaining: 6.05s
# 339:	learn: 0.0769997	total: 3.11s	remaining: 6.04s
# 340:	learn: 0.0769228	total: 3.12s	remaining: 6.03s
# 341:	learn: 0.0769149	total: 3.13s	remaining: 6.02s
# 342:	learn: 0.0768536	total: 3.14s	remaining: 6.01s
# 343:	learn: 0.0768400	total: 3.15s	remaining: 6s
# 344:	learn: 0.0767764	total: 3.16s	remaining: 5.99s
# 345:	learn: 0.0767431	total: 3.16s	remaining: 5.98s
# 346:	learn: 0.0767123	total: 3.17s	remaining: 5.97s
# 347:	learn: 0.0766639	total: 3.18s	remaining: 5.96s
# 348:	learn: 0.0765614	total: 3.19s	remaining: 5.95s
# 349:	learn: 0.0765239	total: 3.2s	remaining: 5.94s
# 350:	learn: 0.0764860	total: 3.21s	remaining: 5.93s
# 351:	learn: 0.0764261	total: 3.22s	remaining: 5.92s
# 352:	learn: 0.0763959	total: 3.23s	remaining: 5.91s
# 353:	learn: 0.0763560	total: 3.23s	remaining: 5.9s
# 354:	learn: 0.0762980	total: 3.24s	remaining: 5.89s
# 355:	learn: 0.0762735	total: 3.25s	remaining: 5.88s
# 356:	learn: 0.0762440	total: 3.26s	remaining: 5.87s
# 357:	learn: 0.0761564	total: 3.27s	remaining: 5.86s
# 358:	learn: 0.0761480	total: 3.28s	remaining: 5.85s
# 359:	learn: 0.0760520	total: 3.29s	remaining: 5.84s
# 360:	learn: 0.0760479	total: 3.29s	remaining: 5.83s
# 361:	learn: 0.0760376	total: 3.3s	remaining: 5.82s
# 362:	learn: 0.0759825	total: 3.31s	remaining: 5.81s
# 363:	learn: 0.0758855	total: 3.32s	remaining: 5.8s
# 364:	learn: 0.0758461	total: 3.33s	remaining: 5.79s
# 365:	learn: 0.0758139	total: 3.34s	remaining: 5.79s
# 366:	learn: 0.0757711	total: 3.35s	remaining: 5.78s
# 367:	learn: 0.0757530	total: 3.36s	remaining: 5.77s
# 368:	learn: 0.0757004	total: 3.37s	remaining: 5.76s
# 369:	learn: 0.0756749	total: 3.38s	remaining: 5.75s
# 370:	learn: 0.0756336	total: 3.39s	remaining: 5.74s
# 371:	learn: 0.0755974	total: 3.4s	remaining: 5.73s
# 372:	learn: 0.0754887	total: 3.41s	remaining: 5.73s
# 373:	learn: 0.0753719	total: 3.41s	remaining: 5.71s
# 374:	learn: 0.0753108	total: 3.42s	remaining: 5.7s
# 375:	learn: 0.0752541	total: 3.43s	remaining: 5.69s
# 376:	learn: 0.0752132	total: 3.44s	remaining: 5.68s
# 377:	learn: 0.0751908	total: 3.45s	remaining: 5.67s
# 378:	learn: 0.0751601	total: 3.46s	remaining: 5.66s
# 379:	learn: 0.0751082	total: 3.46s	remaining: 5.65s
# 380:	learn: 0.0750468	total: 3.47s	remaining: 5.64s
# 381:	learn: 0.0749319	total: 3.48s	remaining: 5.63s
# 382:	learn: 0.0748671	total: 3.49s	remaining: 5.62s
# 383:	learn: 0.0748105	total: 3.5s	remaining: 5.61s
# 384:	learn: 0.0747785	total: 3.51s	remaining: 5.6s
# 385:	learn: 0.0747147	total: 3.52s	remaining: 5.59s
# 386:	learn: 0.0746516	total: 3.52s	remaining: 5.58s
# 387:	learn: 0.0745888	total: 3.53s	remaining: 5.57s
# 388:	learn: 0.0745693	total: 3.54s	remaining: 5.56s
# 389:	learn: 0.0745263	total: 3.55s	remaining: 5.55s
# 390:	learn: 0.0744581	total: 3.56s	remaining: 5.54s
# 391:	learn: 0.0744300	total: 3.57s	remaining: 5.53s
# 392:	learn: 0.0743572	total: 3.58s	remaining: 5.52s
# 393:	learn: 0.0742940	total: 3.58s	remaining: 5.51s
# 394:	learn: 0.0742784	total: 3.6s	remaining: 5.51s
# 395:	learn: 0.0741956	total: 3.6s	remaining: 5.5s
# 396:	learn: 0.0741810	total: 3.61s	remaining: 5.49s
# 397:	learn: 0.0741000	total: 3.62s	remaining: 5.48s
# 398:	learn: 0.0740955	total: 3.63s	remaining: 5.47s
# 399:	learn: 0.0740568	total: 3.64s	remaining: 5.46s
# 400:	learn: 0.0740004	total: 3.65s	remaining: 5.45s
# 401:	learn: 0.0739895	total: 3.66s	remaining: 5.44s
# 402:	learn: 0.0739538	total: 3.67s	remaining: 5.43s
# 403:	learn: 0.0739429	total: 3.68s	remaining: 5.43s
# 404:	learn: 0.0738892	total: 3.69s	remaining: 5.42s
# 405:	learn: 0.0738415	total: 3.7s	remaining: 5.41s
# 406:	learn: 0.0738217	total: 3.71s	remaining: 5.4s
# 407:	learn: 0.0737641	total: 3.71s	remaining: 5.39s
# 408:	learn: 0.0737038	total: 3.72s	remaining: 5.38s
# 409:	learn: 0.0736554	total: 3.73s	remaining: 5.37s
# 410:	learn: 0.0736128	total: 3.74s	remaining: 5.36s
# 411:	learn: 0.0735926	total: 3.75s	remaining: 5.35s
# 412:	learn: 0.0735727	total: 3.76s	remaining: 5.34s
# 413:	learn: 0.0735500	total: 3.77s	remaining: 5.34s
# 414:	learn: 0.0734318	total: 3.78s	remaining: 5.33s
# 415:	learn: 0.0733807	total: 3.79s	remaining: 5.32s
# 416:	learn: 0.0733464	total: 3.8s	remaining: 5.31s
# 417:	learn: 0.0732971	total: 3.81s	remaining: 5.3s
# 418:	learn: 0.0732710	total: 3.81s	remaining: 5.29s
# 419:	learn: 0.0732369	total: 3.82s	remaining: 5.28s
# 420:	learn: 0.0731734	total: 3.83s	remaining: 5.27s
# 421:	learn: 0.0731383	total: 3.84s	remaining: 5.26s
# 422:	learn: 0.0731176	total: 3.85s	remaining: 5.25s
# 423:	learn: 0.0730627	total: 3.86s	remaining: 5.24s
# 424:	learn: 0.0730149	total: 3.87s	remaining: 5.23s
# 425:	learn: 0.0729927	total: 3.88s	remaining: 5.22s
# 426:	learn: 0.0728767	total: 3.88s	remaining: 5.21s
# 427:	learn: 0.0728692	total: 3.89s	remaining: 5.2s
# 428:	learn: 0.0728549	total: 3.9s	remaining: 5.2s
# 429:	learn: 0.0728218	total: 3.91s	remaining: 5.19s
# 430:	learn: 0.0727603	total: 3.92s	remaining: 5.18s
# 431:	learn: 0.0727471	total: 3.93s	remaining: 5.17s
# 432:	learn: 0.0727203	total: 3.94s	remaining: 5.16s
# 433:	learn: 0.0726830	total: 3.95s	remaining: 5.15s
# 434:	learn: 0.0726738	total: 3.96s	remaining: 5.14s
# 435:	learn: 0.0726464	total: 3.97s	remaining: 5.14s
# 436:	learn: 0.0726122	total: 3.98s	remaining: 5.13s
# 437:	learn: 0.0725692	total: 3.99s	remaining: 5.12s
# 438:	learn: 0.0725307	total: 4s	remaining: 5.11s
# 439:	learn: 0.0724910	total: 4.01s	remaining: 5.1s
# 440:	learn: 0.0724776	total: 4.02s	remaining: 5.09s
# 441:	learn: 0.0724691	total: 4.03s	remaining: 5.08s
# 442:	learn: 0.0724068	total: 4.03s	remaining: 5.07s
# 443:	learn: 0.0723940	total: 4.04s	remaining: 5.06s
# 444:	learn: 0.0723053	total: 4.05s	remaining: 5.05s
# 445:	learn: 0.0722694	total: 4.06s	remaining: 5.05s
# 446:	learn: 0.0722520	total: 4.07s	remaining: 5.04s
# 447:	learn: 0.0722256	total: 4.08s	remaining: 5.03s
# 448:	learn: 0.0722055	total: 4.09s	remaining: 5.02s
# 449:	learn: 0.0721869	total: 4.1s	remaining: 5.01s
# 450:	learn: 0.0721450	total: 4.11s	remaining: 5s
# 451:	learn: 0.0721404	total: 4.12s	remaining: 4.99s
# 452:	learn: 0.0720973	total: 4.13s	remaining: 4.98s
# 453:	learn: 0.0720688	total: 4.14s	remaining: 4.97s
# 454:	learn: 0.0720378	total: 4.16s	remaining: 4.99s
# 455:	learn: 0.0720169	total: 4.17s	remaining: 4.98s
# 456:	learn: 0.0720068	total: 4.18s	remaining: 4.97s
# 457:	learn: 0.0719962	total: 4.19s	remaining: 4.96s
# 458:	learn: 0.0719728	total: 4.2s	remaining: 4.95s
# 459:	learn: 0.0719290	total: 4.21s	remaining: 4.94s
# 460:	learn: 0.0719175	total: 4.22s	remaining: 4.93s
# 461:	learn: 0.0718608	total: 4.23s	remaining: 4.92s
# 462:	learn: 0.0718197	total: 4.24s	remaining: 4.91s
# 463:	learn: 0.0718062	total: 4.25s	remaining: 4.9s
# 464:	learn: 0.0717514	total: 4.25s	remaining: 4.89s
# 465:	learn: 0.0717026	total: 4.26s	remaining: 4.88s
# 466:	learn: 0.0716968	total: 4.27s	remaining: 4.87s
# 467:	learn: 0.0716734	total: 4.28s	remaining: 4.86s
# 468:	learn: 0.0716367	total: 4.29s	remaining: 4.85s
# 469:	learn: 0.0716234	total: 4.3s	remaining: 4.84s
# 470:	learn: 0.0716052	total: 4.3s	remaining: 4.83s
# 471:	learn: 0.0715675	total: 4.31s	remaining: 4.83s
# 472:	learn: 0.0715342	total: 4.32s	remaining: 4.82s
# 473:	learn: 0.0715126	total: 4.33s	remaining: 4.81s
# 474:	learn: 0.0714710	total: 4.34s	remaining: 4.8s
# 475:	learn: 0.0714430	total: 4.35s	remaining: 4.79s
# 476:	learn: 0.0714169	total: 4.36s	remaining: 4.78s
# 477:	learn: 0.0713518	total: 4.36s	remaining: 4.77s
# 478:	learn: 0.0713120	total: 4.37s	remaining: 4.75s
# 479:	learn: 0.0712852	total: 4.38s	remaining: 4.75s
# 480:	learn: 0.0712224	total: 4.39s	remaining: 4.74s
# 481:	learn: 0.0711748	total: 4.4s	remaining: 4.72s
# 482:	learn: 0.0711433	total: 4.4s	remaining: 4.71s
# 483:	learn: 0.0711039	total: 4.41s	remaining: 4.7s
# 484:	learn: 0.0710545	total: 4.42s	remaining: 4.69s
# 485:	learn: 0.0710070	total: 4.43s	remaining: 4.68s
# 486:	learn: 0.0709777	total: 4.44s	remaining: 4.67s
# 487:	learn: 0.0709356	total: 4.44s	remaining: 4.66s
# 488:	learn: 0.0709079	total: 4.45s	remaining: 4.65s
# 489:	learn: 0.0708847	total: 4.46s	remaining: 4.64s
# 490:	learn: 0.0708519	total: 4.47s	remaining: 4.63s
# 491:	learn: 0.0708375	total: 4.48s	remaining: 4.62s
# 492:	learn: 0.0708070	total: 4.49s	remaining: 4.61s
# 493:	learn: 0.0707164	total: 4.5s	remaining: 4.6s
# 494:	learn: 0.0706888	total: 4.5s	remaining: 4.59s
# 495:	learn: 0.0706282	total: 4.51s	remaining: 4.58s
# 496:	learn: 0.0705970	total: 4.52s	remaining: 4.58s
# 497:	learn: 0.0705594	total: 4.53s	remaining: 4.57s
# 498:	learn: 0.0705249	total: 4.54s	remaining: 4.55s
# 499:	learn: 0.0704607	total: 4.54s	remaining: 4.54s
# 500:	learn: 0.0704441	total: 4.55s	remaining: 4.54s
# 501:	learn: 0.0704116	total: 4.56s	remaining: 4.53s
# 502:	learn: 0.0703577	total: 4.57s	remaining: 4.51s
# 503:	learn: 0.0703368	total: 4.58s	remaining: 4.51s
# 504:	learn: 0.0702923	total: 4.59s	remaining: 4.5s
# 505:	learn: 0.0702732	total: 4.6s	remaining: 4.49s
# 506:	learn: 0.0702565	total: 4.6s	remaining: 4.48s
# 507:	learn: 0.0702202	total: 4.61s	remaining: 4.47s
# 508:	learn: 0.0701846	total: 4.62s	remaining: 4.46s
# 509:	learn: 0.0701296	total: 4.63s	remaining: 4.45s
# 510:	learn: 0.0700955	total: 4.64s	remaining: 4.44s
# 511:	learn: 0.0700670	total: 4.65s	remaining: 4.43s
# 512:	learn: 0.0700267	total: 4.66s	remaining: 4.42s
# 513:	learn: 0.0699166	total: 4.66s	remaining: 4.41s
# 514:	learn: 0.0698873	total: 4.67s	remaining: 4.4s
# 515:	learn: 0.0698734	total: 4.68s	remaining: 4.39s
# 516:	learn: 0.0698497	total: 4.69s	remaining: 4.38s
# 517:	learn: 0.0698342	total: 4.7s	remaining: 4.37s
# 518:	learn: 0.0698233	total: 4.71s	remaining: 4.37s
# 519:	learn: 0.0698110	total: 4.72s	remaining: 4.36s
# 520:	learn: 0.0697589	total: 4.73s	remaining: 4.35s
# 521:	learn: 0.0697337	total: 4.74s	remaining: 4.34s
# 522:	learn: 0.0696883	total: 4.75s	remaining: 4.33s
# 523:	learn: 0.0696532	total: 4.75s	remaining: 4.32s
# 524:	learn: 0.0696352	total: 4.76s	remaining: 4.31s
# 525:	learn: 0.0695782	total: 4.77s	remaining: 4.3s
# 526:	learn: 0.0695234	total: 4.78s	remaining: 4.29s
# 527:	learn: 0.0694822	total: 4.79s	remaining: 4.28s
# 528:	learn: 0.0694445	total: 4.8s	remaining: 4.27s
# 529:	learn: 0.0694281	total: 4.8s	remaining: 4.26s
# 530:	learn: 0.0693821	total: 4.81s	remaining: 4.25s
# 531:	learn: 0.0693528	total: 4.82s	remaining: 4.24s
# 532:	learn: 0.0693167	total: 4.83s	remaining: 4.23s
# 533:	learn: 0.0692777	total: 4.84s	remaining: 4.22s
# 534:	learn: 0.0692391	total: 4.85s	remaining: 4.22s
# 535:	learn: 0.0692069	total: 4.86s	remaining: 4.21s
# 536:	learn: 0.0691890	total: 4.87s	remaining: 4.2s
# 537:	learn: 0.0691746	total: 4.88s	remaining: 4.19s
# 538:	learn: 0.0691471	total: 4.89s	remaining: 4.18s
# 539:	learn: 0.0691084	total: 4.9s	remaining: 4.17s
# 540:	learn: 0.0690691	total: 4.91s	remaining: 4.16s
# 541:	learn: 0.0690401	total: 4.92s	remaining: 4.16s
# 542:	learn: 0.0690363	total: 4.92s	remaining: 4.14s
# 543:	learn: 0.0690051	total: 4.93s	remaining: 4.14s
# 544:	learn: 0.0689606	total: 4.94s	remaining: 4.13s
# 545:	learn: 0.0689188	total: 4.95s	remaining: 4.12s
# 546:	learn: 0.0689033	total: 4.96s	remaining: 4.11s
# 547:	learn: 0.0688760	total: 4.97s	remaining: 4.1s
# 548:	learn: 0.0688016	total: 4.98s	remaining: 4.09s
# 549:	learn: 0.0687783	total: 4.99s	remaining: 4.08s
# 550:	learn: 0.0687623	total: 5s	remaining: 4.07s
# 551:	learn: 0.0687294	total: 5s	remaining: 4.06s
# 552:	learn: 0.0686971	total: 5.01s	remaining: 4.05s
# 553:	learn: 0.0686788	total: 5.02s	remaining: 4.04s
# 554:	learn: 0.0686306	total: 5.03s	remaining: 4.03s
# 555:	learn: 0.0686145	total: 5.04s	remaining: 4.02s
# 556:	learn: 0.0685865	total: 5.05s	remaining: 4.01s
# 557:	learn: 0.0685600	total: 5.06s	remaining: 4s
# 558:	learn: 0.0685273	total: 5.07s	remaining: 4s
# 559:	learn: 0.0685030	total: 5.08s	remaining: 3.99s
# 560:	learn: 0.0684810	total: 5.08s	remaining: 3.98s
# 561:	learn: 0.0684720	total: 5.1s	remaining: 3.97s
# 562:	learn: 0.0684399	total: 5.11s	remaining: 3.96s
# 563:	learn: 0.0683955	total: 5.12s	remaining: 3.95s
# 564:	learn: 0.0683676	total: 5.12s	remaining: 3.94s
# 565:	learn: 0.0683536	total: 5.13s	remaining: 3.94s
# 566:	learn: 0.0683275	total: 5.14s	remaining: 3.93s
# 567:	learn: 0.0682952	total: 5.15s	remaining: 3.92s
# 568:	learn: 0.0682610	total: 5.16s	remaining: 3.91s
# 569:	learn: 0.0682184	total: 5.17s	remaining: 3.9s
# 570:	learn: 0.0682092	total: 5.18s	remaining: 3.89s
# 571:	learn: 0.0681880	total: 5.18s	remaining: 3.88s
# 572:	learn: 0.0681579	total: 5.19s	remaining: 3.87s
# 573:	learn: 0.0681258	total: 5.2s	remaining: 3.86s
# 574:	learn: 0.0681126	total: 5.21s	remaining: 3.85s
# 575:	learn: 0.0680675	total: 5.22s	remaining: 3.84s
# 576:	learn: 0.0680367	total: 5.23s	remaining: 3.83s
# 577:	learn: 0.0680312	total: 5.24s	remaining: 3.83s
# 578:	learn: 0.0679966	total: 5.25s	remaining: 3.82s
# 579:	learn: 0.0679880	total: 5.26s	remaining: 3.81s
# 580:	learn: 0.0679822	total: 5.27s	remaining: 3.8s
# 581:	learn: 0.0679297	total: 5.27s	remaining: 3.79s
# 582:	learn: 0.0679202	total: 5.28s	remaining: 3.78s
# 583:	learn: 0.0678938	total: 5.29s	remaining: 3.77s
# 584:	learn: 0.0678771	total: 5.3s	remaining: 3.76s
# 585:	learn: 0.0678536	total: 5.31s	remaining: 3.75s
# 586:	learn: 0.0678368	total: 5.32s	remaining: 3.74s
# 587:	learn: 0.0678047	total: 5.33s	remaining: 3.73s
# 588:	learn: 0.0677943	total: 5.34s	remaining: 3.72s
# 589:	learn: 0.0677679	total: 5.35s	remaining: 3.71s
# 590:	learn: 0.0677515	total: 5.36s	remaining: 3.71s
# 591:	learn: 0.0677030	total: 5.36s	remaining: 3.7s
# 592:	learn: 0.0676740	total: 5.37s	remaining: 3.69s
# 593:	learn: 0.0676580	total: 5.38s	remaining: 3.68s
# 594:	learn: 0.0676400	total: 5.39s	remaining: 3.67s
# 595:	learn: 0.0676232	total: 5.4s	remaining: 3.66s
# 596:	learn: 0.0675819	total: 5.41s	remaining: 3.65s
# 597:	learn: 0.0675726	total: 5.42s	remaining: 3.64s
# 598:	learn: 0.0675392	total: 5.42s	remaining: 3.63s
# 599:	learn: 0.0675108	total: 5.43s	remaining: 3.62s
# 600:	learn: 0.0674949	total: 5.44s	remaining: 3.61s
# 601:	learn: 0.0674781	total: 5.45s	remaining: 3.6s
# 602:	learn: 0.0674372	total: 5.46s	remaining: 3.6s
# 603:	learn: 0.0673983	total: 5.47s	remaining: 3.58s
# 604:	learn: 0.0673774	total: 5.48s	remaining: 3.58s
# 605:	learn: 0.0673442	total: 5.49s	remaining: 3.57s
# 606:	learn: 0.0673032	total: 5.5s	remaining: 3.56s
# 607:	learn: 0.0672647	total: 5.5s	remaining: 3.55s
# 608:	learn: 0.0672480	total: 5.51s	remaining: 3.54s
# 609:	learn: 0.0671739	total: 5.52s	remaining: 3.53s
# 610:	learn: 0.0671408	total: 5.53s	remaining: 3.52s
# 611:	learn: 0.0671050	total: 5.54s	remaining: 3.51s
# 612:	learn: 0.0670852	total: 5.55s	remaining: 3.5s
# 613:	learn: 0.0670016	total: 5.56s	remaining: 3.49s
# 614:	learn: 0.0669630	total: 5.57s	remaining: 3.48s
# 615:	learn: 0.0669390	total: 5.58s	remaining: 3.48s
# 616:	learn: 0.0669065	total: 5.58s	remaining: 3.47s
# 617:	learn: 0.0668592	total: 5.59s	remaining: 3.46s
# 618:	learn: 0.0668529	total: 5.6s	remaining: 3.45s
# 619:	learn: 0.0668377	total: 5.61s	remaining: 3.44s
# 620:	learn: 0.0668114	total: 5.62s	remaining: 3.43s
# 621:	learn: 0.0667594	total: 5.63s	remaining: 3.42s
# 622:	learn: 0.0667535	total: 5.64s	remaining: 3.41s
# 623:	learn: 0.0667432	total: 5.65s	remaining: 3.4s
# 624:	learn: 0.0667087	total: 5.66s	remaining: 3.39s
# 625:	learn: 0.0666920	total: 5.66s	remaining: 3.38s
# 626:	learn: 0.0666727	total: 5.67s	remaining: 3.37s
# 627:	learn: 0.0666412	total: 5.68s	remaining: 3.37s
# 628:	learn: 0.0666189	total: 5.69s	remaining: 3.35s
# 629:	learn: 0.0665865	total: 5.7s	remaining: 3.35s
# 630:	learn: 0.0664825	total: 5.71s	remaining: 3.34s
# 631:	learn: 0.0664684	total: 5.72s	remaining: 3.33s
# 632:	learn: 0.0664554	total: 5.73s	remaining: 3.32s
# 633:	learn: 0.0664312	total: 5.74s	remaining: 3.31s
# 634:	learn: 0.0664161	total: 5.75s	remaining: 3.3s
# 635:	learn: 0.0663867	total: 5.75s	remaining: 3.29s
# 636:	learn: 0.0663490	total: 5.76s	remaining: 3.28s
# 637:	learn: 0.0662994	total: 5.77s	remaining: 3.27s
# 638:	learn: 0.0662548	total: 5.78s	remaining: 3.27s
# 639:	learn: 0.0662142	total: 5.79s	remaining: 3.25s
# 640:	learn: 0.0662056	total: 5.8s	remaining: 3.25s
# 641:	learn: 0.0661775	total: 5.8s	remaining: 3.24s
# 642:	learn: 0.0661687	total: 5.81s	remaining: 3.23s
# 643:	learn: 0.0661448	total: 5.82s	remaining: 3.22s
# 644:	learn: 0.0661229	total: 5.83s	remaining: 3.21s
# 645:	learn: 0.0660997	total: 5.84s	remaining: 3.2s
# 646:	learn: 0.0660583	total: 5.85s	remaining: 3.19s
# 647:	learn: 0.0660518	total: 5.86s	remaining: 3.18s
# 648:	learn: 0.0660422	total: 5.87s	remaining: 3.17s
# 649:	learn: 0.0660175	total: 5.87s	remaining: 3.16s
# 650:	learn: 0.0660014	total: 5.88s	remaining: 3.15s
# 651:	learn: 0.0659933	total: 5.89s	remaining: 3.14s
# 652:	learn: 0.0659759	total: 5.9s	remaining: 3.13s
# 653:	learn: 0.0659738	total: 5.91s	remaining: 3.13s
# 654:	learn: 0.0659547	total: 5.92s	remaining: 3.12s
# 655:	learn: 0.0659148	total: 5.92s	remaining: 3.11s
# 656:	learn: 0.0658903	total: 5.93s	remaining: 3.1s
# 657:	learn: 0.0658682	total: 5.94s	remaining: 3.09s
# 658:	learn: 0.0658411	total: 5.95s	remaining: 3.08s
# 659:	learn: 0.0658272	total: 5.96s	remaining: 3.07s
# 660:	learn: 0.0657965	total: 5.97s	remaining: 3.06s
# 661:	learn: 0.0657897	total: 5.98s	remaining: 3.05s
# 662:	learn: 0.0657677	total: 5.99s	remaining: 3.04s
# 663:	learn: 0.0657423	total: 6s	remaining: 3.04s
# 664:	learn: 0.0657147	total: 6.01s	remaining: 3.03s
# 665:	learn: 0.0656754	total: 6.02s	remaining: 3.02s
# 666:	learn: 0.0656573	total: 6.03s	remaining: 3.01s
# 667:	learn: 0.0656339	total: 6.04s	remaining: 3s
# 668:	learn: 0.0656056	total: 6.05s	remaining: 2.99s
# 669:	learn: 0.0655722	total: 6.06s	remaining: 2.98s
# 670:	learn: 0.0655469	total: 6.07s	remaining: 2.97s
# 671:	learn: 0.0655238	total: 6.08s	remaining: 2.97s
# 672:	learn: 0.0655189	total: 6.08s	remaining: 2.96s
# 673:	learn: 0.0655070	total: 6.09s	remaining: 2.95s
# 674:	learn: 0.0654373	total: 6.11s	remaining: 2.94s
# 675:	learn: 0.0654330	total: 6.12s	remaining: 2.93s
# 676:	learn: 0.0653830	total: 6.13s	remaining: 2.92s
# 677:	learn: 0.0653455	total: 6.14s	remaining: 2.91s
# 678:	learn: 0.0653153	total: 6.15s	remaining: 2.91s
# 679:	learn: 0.0652979	total: 6.16s	remaining: 2.9s
# 680:	learn: 0.0652704	total: 6.17s	remaining: 2.89s
# 681:	learn: 0.0652486	total: 6.18s	remaining: 2.88s
# 682:	learn: 0.0652096	total: 6.19s	remaining: 2.87s
# 683:	learn: 0.0652003	total: 6.2s	remaining: 2.87s
# 684:	learn: 0.0651749	total: 6.21s	remaining: 2.86s
# 685:	learn: 0.0651577	total: 6.22s	remaining: 2.85s
# 686:	learn: 0.0651435	total: 6.23s	remaining: 2.84s
# 687:	learn: 0.0651215	total: 6.24s	remaining: 2.83s
# 688:	learn: 0.0650999	total: 6.25s	remaining: 2.82s
# 689:	learn: 0.0650499	total: 6.26s	remaining: 2.81s
# 690:	learn: 0.0650310	total: 6.27s	remaining: 2.8s
# 691:	learn: 0.0650307	total: 6.28s	remaining: 2.79s
# 692:	learn: 0.0650255	total: 6.29s	remaining: 2.79s
# 693:	learn: 0.0650190	total: 6.3s	remaining: 2.78s
# 694:	learn: 0.0649865	total: 6.3s	remaining: 2.77s
# 695:	learn: 0.0649612	total: 6.32s	remaining: 2.76s
# 696:	learn: 0.0649440	total: 6.32s	remaining: 2.75s
# 697:	learn: 0.0649125	total: 6.33s	remaining: 2.74s
# 698:	learn: 0.0648510	total: 6.34s	remaining: 2.73s
# 699:	learn: 0.0648258	total: 6.35s	remaining: 2.72s
# 700:	learn: 0.0647931	total: 6.36s	remaining: 2.71s
# 701:	learn: 0.0647654	total: 6.37s	remaining: 2.7s
# 702:	learn: 0.0647371	total: 6.37s	remaining: 2.69s
# 703:	learn: 0.0647195	total: 6.38s	remaining: 2.68s
# 704:	learn: 0.0646851	total: 6.39s	remaining: 2.67s
# 705:	learn: 0.0646185	total: 6.4s	remaining: 2.66s
# 706:	learn: 0.0645972	total: 6.41s	remaining: 2.65s
# 707:	learn: 0.0645720	total: 6.42s	remaining: 2.65s
# 708:	learn: 0.0645305	total: 6.42s	remaining: 2.64s
# 709:	learn: 0.0644979	total: 6.43s	remaining: 2.63s
# 710:	learn: 0.0644651	total: 6.44s	remaining: 2.62s
# 711:	learn: 0.0644393	total: 6.45s	remaining: 2.61s
# 712:	learn: 0.0644169	total: 6.46s	remaining: 2.6s
# 713:	learn: 0.0643534	total: 6.46s	remaining: 2.59s
# 714:	learn: 0.0643410	total: 6.47s	remaining: 2.58s
# 715:	learn: 0.0643272	total: 6.48s	remaining: 2.57s
# 716:	learn: 0.0643119	total: 6.49s	remaining: 2.56s
# 717:	learn: 0.0642850	total: 6.5s	remaining: 2.55s
# 718:	learn: 0.0642775	total: 6.51s	remaining: 2.54s
# 719:	learn: 0.0642682	total: 6.51s	remaining: 2.53s
# 720:	learn: 0.0642522	total: 6.52s	remaining: 2.52s
# 721:	learn: 0.0642286	total: 6.53s	remaining: 2.52s
# 722:	learn: 0.0641603	total: 6.54s	remaining: 2.51s
# 723:	learn: 0.0641209	total: 6.55s	remaining: 2.5s
# 724:	learn: 0.0641023	total: 6.56s	remaining: 2.49s
# 725:	learn: 0.0640895	total: 6.57s	remaining: 2.48s
# 726:	learn: 0.0640688	total: 6.57s	remaining: 2.47s
# 727:	learn: 0.0640414	total: 6.58s	remaining: 2.46s
# 728:	learn: 0.0640103	total: 6.59s	remaining: 2.45s
# 729:	learn: 0.0638937	total: 6.6s	remaining: 2.44s
# 730:	learn: 0.0638640	total: 6.61s	remaining: 2.43s
# 731:	learn: 0.0638347	total: 6.61s	remaining: 2.42s
# 732:	learn: 0.0637933	total: 6.62s	remaining: 2.41s
# 733:	learn: 0.0637609	total: 6.63s	remaining: 2.4s
# 734:	learn: 0.0637476	total: 6.64s	remaining: 2.39s
# 735:	learn: 0.0637299	total: 6.65s	remaining: 2.38s
# 736:	learn: 0.0636911	total: 6.66s	remaining: 2.38s
# 737:	learn: 0.0636765	total: 6.67s	remaining: 2.37s
# 738:	learn: 0.0636268	total: 6.67s	remaining: 2.36s
# 739:	learn: 0.0636068	total: 6.68s	remaining: 2.35s
# 740:	learn: 0.0635806	total: 6.69s	remaining: 2.34s
# 741:	learn: 0.0635597	total: 6.7s	remaining: 2.33s
# 742:	learn: 0.0635292	total: 6.71s	remaining: 2.32s
# 743:	learn: 0.0635238	total: 6.71s	remaining: 2.31s
# 744:	learn: 0.0635005	total: 6.72s	remaining: 2.3s
# 745:	learn: 0.0634760	total: 6.73s	remaining: 2.29s
# 746:	learn: 0.0634239	total: 6.74s	remaining: 2.28s
# 747:	learn: 0.0633809	total: 6.75s	remaining: 2.27s
# 748:	learn: 0.0633752	total: 6.76s	remaining: 2.27s
# 749:	learn: 0.0633550	total: 6.77s	remaining: 2.25s
# 750:	learn: 0.0633090	total: 6.78s	remaining: 2.25s
# 751:	learn: 0.0633065	total: 6.78s	remaining: 2.24s
# 752:	learn: 0.0632852	total: 6.79s	remaining: 2.23s
# 753:	learn: 0.0632569	total: 6.8s	remaining: 2.22s
# 754:	learn: 0.0632435	total: 6.81s	remaining: 2.21s
# 755:	learn: 0.0632002	total: 6.82s	remaining: 2.2s
# 756:	learn: 0.0631824	total: 6.83s	remaining: 2.19s
# 757:	learn: 0.0631557	total: 6.83s	remaining: 2.18s
# 758:	learn: 0.0631369	total: 6.84s	remaining: 2.17s
# 759:	learn: 0.0631092	total: 6.85s	remaining: 2.16s
# 760:	learn: 0.0630909	total: 6.86s	remaining: 2.15s
# 761:	learn: 0.0630479	total: 6.87s	remaining: 2.15s
# 762:	learn: 0.0630039	total: 6.88s	remaining: 2.14s
# 763:	learn: 0.0629793	total: 6.89s	remaining: 2.13s
# 764:	learn: 0.0629488	total: 6.89s	remaining: 2.12s
# 765:	learn: 0.0629077	total: 6.9s	remaining: 2.11s
# 766:	learn: 0.0628765	total: 6.91s	remaining: 2.1s
# 767:	learn: 0.0628290	total: 6.92s	remaining: 2.09s
# 768:	learn: 0.0627733	total: 6.93s	remaining: 2.08s
# 769:	learn: 0.0627225	total: 6.93s	remaining: 2.07s
# 770:	learn: 0.0627012	total: 6.94s	remaining: 2.06s
# 771:	learn: 0.0626764	total: 6.95s	remaining: 2.05s
# 772:	learn: 0.0626612	total: 6.96s	remaining: 2.04s
# 773:	learn: 0.0626404	total: 6.97s	remaining: 2.04s
# 774:	learn: 0.0626346	total: 6.98s	remaining: 2.03s
# 775:	learn: 0.0626082	total: 6.99s	remaining: 2.02s
# 776:	learn: 0.0625721	total: 7s	remaining: 2.01s
# 777:	learn: 0.0625600	total: 7.01s	remaining: 2s
# 778:	learn: 0.0625255	total: 7.02s	remaining: 1.99s
# 779:	learn: 0.0624977	total: 7.03s	remaining: 1.98s
# 780:	learn: 0.0624785	total: 7.04s	remaining: 1.98s
# 781:	learn: 0.0624560	total: 7.05s	remaining: 1.97s
# 782:	learn: 0.0624271	total: 7.07s	remaining: 1.96s
# 783:	learn: 0.0624047	total: 7.08s	remaining: 1.95s
# 784:	learn: 0.0623804	total: 7.08s	remaining: 1.94s
# 785:	learn: 0.0623751	total: 7.09s	remaining: 1.93s
# 786:	learn: 0.0623610	total: 7.11s	remaining: 1.92s
# 787:	learn: 0.0623320	total: 7.12s	remaining: 1.91s
# 788:	learn: 0.0623035	total: 7.13s	remaining: 1.91s
# 789:	learn: 0.0622877	total: 7.13s	remaining: 1.9s
# 790:	learn: 0.0622084	total: 7.14s	remaining: 1.89s
# 791:	learn: 0.0621729	total: 7.16s	remaining: 1.88s
# 792:	learn: 0.0621158	total: 7.16s	remaining: 1.87s
# 793:	learn: 0.0620814	total: 7.17s	remaining: 1.86s
# 794:	learn: 0.0620559	total: 7.18s	remaining: 1.85s
# 795:	learn: 0.0620189	total: 7.19s	remaining: 1.84s
# 796:	learn: 0.0619890	total: 7.2s	remaining: 1.83s
# 797:	learn: 0.0619611	total: 7.21s	remaining: 1.82s
# 798:	learn: 0.0619489	total: 7.22s	remaining: 1.82s
# 799:	learn: 0.0619473	total: 7.23s	remaining: 1.81s
# 800:	learn: 0.0619157	total: 7.24s	remaining: 1.8s
# 801:	learn: 0.0618949	total: 7.25s	remaining: 1.79s
# 802:	learn: 0.0618697	total: 7.25s	remaining: 1.78s
# 803:	learn: 0.0618486	total: 7.26s	remaining: 1.77s
# 804:	learn: 0.0618263	total: 7.27s	remaining: 1.76s
# 805:	learn: 0.0617944	total: 7.28s	remaining: 1.75s
# 806:	learn: 0.0617727	total: 7.29s	remaining: 1.74s
# 807:	learn: 0.0617473	total: 7.3s	remaining: 1.73s
# 808:	learn: 0.0617352	total: 7.3s	remaining: 1.72s
# 809:	learn: 0.0617030	total: 7.31s	remaining: 1.72s
# 810:	learn: 0.0616899	total: 7.32s	remaining: 1.71s
# 811:	learn: 0.0616773	total: 7.33s	remaining: 1.7s
# 812:	learn: 0.0616557	total: 7.34s	remaining: 1.69s
# 813:	learn: 0.0616250	total: 7.35s	remaining: 1.68s
# 814:	learn: 0.0616133	total: 7.36s	remaining: 1.67s
# 815:	learn: 0.0615647	total: 7.36s	remaining: 1.66s
# 816:	learn: 0.0615062	total: 7.37s	remaining: 1.65s
# 817:	learn: 0.0614629	total: 7.38s	remaining: 1.64s
# 818:	learn: 0.0614367	total: 7.39s	remaining: 1.63s
# 819:	learn: 0.0614150	total: 7.4s	remaining: 1.62s
# 820:	learn: 0.0613916	total: 7.41s	remaining: 1.61s
# 821:	learn: 0.0613703	total: 7.41s	remaining: 1.6s
# 822:	learn: 0.0613531	total: 7.42s	remaining: 1.6s
# 823:	learn: 0.0613115	total: 7.43s	remaining: 1.59s
# 824:	learn: 0.0612821	total: 7.44s	remaining: 1.58s
# 825:	learn: 0.0612744	total: 7.45s	remaining: 1.57s
# 826:	learn: 0.0612289	total: 7.45s	remaining: 1.56s
# 827:	learn: 0.0612275	total: 7.46s	remaining: 1.55s
# 828:	learn: 0.0612131	total: 7.47s	remaining: 1.54s
# 829:	learn: 0.0611871	total: 7.48s	remaining: 1.53s
# 830:	learn: 0.0611644	total: 7.49s	remaining: 1.52s
# 831:	learn: 0.0611542	total: 7.49s	remaining: 1.51s
# 832:	learn: 0.0611259	total: 7.5s	remaining: 1.5s
# 833:	learn: 0.0611038	total: 7.51s	remaining: 1.49s
# 834:	learn: 0.0610672	total: 7.52s	remaining: 1.49s
# 835:	learn: 0.0610409	total: 7.53s	remaining: 1.48s
# 836:	learn: 0.0610036	total: 7.53s	remaining: 1.47s
# 837:	learn: 0.0610016	total: 7.54s	remaining: 1.46s
# 838:	learn: 0.0609715	total: 7.55s	remaining: 1.45s
# 839:	learn: 0.0609365	total: 7.56s	remaining: 1.44s
# 840:	learn: 0.0609257	total: 7.57s	remaining: 1.43s
# 841:	learn: 0.0608953	total: 7.57s	remaining: 1.42s
# 842:	learn: 0.0608625	total: 7.58s	remaining: 1.41s
# 843:	learn: 0.0608462	total: 7.59s	remaining: 1.4s
# 844:	learn: 0.0608251	total: 7.6s	remaining: 1.39s
# 845:	learn: 0.0608029	total: 7.61s	remaining: 1.38s
# 846:	learn: 0.0607847	total: 7.61s	remaining: 1.38s
# 847:	learn: 0.0607694	total: 7.62s	remaining: 1.37s
# 848:	learn: 0.0607487	total: 7.63s	remaining: 1.36s
# 849:	learn: 0.0607301	total: 7.64s	remaining: 1.35s
# 850:	learn: 0.0607188	total: 7.65s	remaining: 1.34s
# 851:	learn: 0.0606925	total: 7.66s	remaining: 1.33s
# 852:	learn: 0.0606714	total: 7.66s	remaining: 1.32s
# 853:	learn: 0.0606504	total: 7.67s	remaining: 1.31s
# 854:	learn: 0.0606235	total: 7.68s	remaining: 1.3s
# 855:	learn: 0.0606004	total: 7.69s	remaining: 1.29s
# 856:	learn: 0.0605626	total: 7.7s	remaining: 1.28s
# 857:	learn: 0.0605188	total: 7.7s	remaining: 1.27s
# 858:	learn: 0.0605003	total: 7.71s	remaining: 1.26s
# 859:	learn: 0.0604774	total: 7.72s	remaining: 1.26s
# 860:	learn: 0.0604586	total: 7.73s	remaining: 1.25s
# 861:	learn: 0.0604364	total: 7.74s	remaining: 1.24s
# 862:	learn: 0.0604252	total: 7.74s	remaining: 1.23s
# 863:	learn: 0.0604026	total: 7.75s	remaining: 1.22s
# 864:	learn: 0.0603883	total: 7.76s	remaining: 1.21s
# 865:	learn: 0.0603471	total: 7.77s	remaining: 1.2s
# 866:	learn: 0.0603293	total: 7.78s	remaining: 1.19s
# 867:	learn: 0.0603074	total: 7.79s	remaining: 1.19s
# 868:	learn: 0.0602843	total: 7.8s	remaining: 1.18s
# 869:	learn: 0.0602578	total: 7.81s	remaining: 1.17s
# 870:	learn: 0.0602165	total: 7.82s	remaining: 1.16s
# 871:	learn: 0.0601863	total: 7.83s	remaining: 1.15s
# 872:	learn: 0.0601760	total: 7.84s	remaining: 1.14s
# 873:	learn: 0.0601622	total: 7.85s	remaining: 1.13s
# 874:	learn: 0.0601376	total: 7.85s	remaining: 1.12s
# 875:	learn: 0.0601009	total: 7.86s	remaining: 1.11s
# 876:	learn: 0.0600825	total: 7.87s	remaining: 1.1s
# 877:	learn: 0.0600720	total: 7.88s	remaining: 1.09s
# 878:	learn: 0.0600623	total: 7.89s	remaining: 1.08s
# 879:	learn: 0.0600379	total: 7.89s	remaining: 1.08s
# 880:	learn: 0.0600292	total: 7.9s	remaining: 1.07s
# 881:	learn: 0.0600116	total: 7.91s	remaining: 1.06s
# 882:	learn: 0.0600008	total: 7.92s	remaining: 1.05s
# 883:	learn: 0.0599802	total: 7.93s	remaining: 1.04s
# 884:	learn: 0.0599631	total: 7.94s	remaining: 1.03s
# 885:	learn: 0.0599321	total: 7.95s	remaining: 1.02s
# 886:	learn: 0.0599306	total: 7.96s	remaining: 1.01s
# 887:	learn: 0.0599190	total: 7.97s	remaining: 1s
# 888:	learn: 0.0599008	total: 7.98s	remaining: 997ms
# 889:	learn: 0.0598852	total: 7.99s	remaining: 988ms
# 890:	learn: 0.0598694	total: 8s	remaining: 979ms
# 891:	learn: 0.0598307	total: 8.01s	remaining: 970ms
# 892:	learn: 0.0598054	total: 8.02s	remaining: 961ms
# 893:	learn: 0.0597837	total: 8.03s	remaining: 952ms
# 894:	learn: 0.0597723	total: 8.04s	remaining: 943ms
# 895:	learn: 0.0597468	total: 8.04s	remaining: 934ms
# 896:	learn: 0.0597168	total: 8.05s	remaining: 925ms
# 897:	learn: 0.0597109	total: 8.06s	remaining: 916ms
# 898:	learn: 0.0596987	total: 8.07s	remaining: 907ms
# 899:	learn: 0.0596692	total: 8.08s	remaining: 898ms
# 900:	learn: 0.0596499	total: 8.09s	remaining: 889ms
# 901:	learn: 0.0596142	total: 8.1s	remaining: 880ms
# 902:	learn: 0.0595867	total: 8.11s	remaining: 871ms
# 903:	learn: 0.0595867	total: 8.11s	remaining: 862ms
# 904:	learn: 0.0595628	total: 8.12s	remaining: 853ms
# 905:	learn: 0.0595428	total: 8.13s	remaining: 844ms
# 906:	learn: 0.0595111	total: 8.14s	remaining: 835ms
# 907:	learn: 0.0594730	total: 8.15s	remaining: 826ms
# 908:	learn: 0.0594557	total: 8.16s	remaining: 817ms
# 909:	learn: 0.0594356	total: 8.17s	remaining: 808ms
# 910:	learn: 0.0594209	total: 8.18s	remaining: 799ms
# 911:	learn: 0.0593883	total: 8.18s	remaining: 790ms
# 912:	learn: 0.0593577	total: 8.19s	remaining: 781ms
# 913:	learn: 0.0593185	total: 8.2s	remaining: 772ms
# 914:	learn: 0.0592824	total: 8.21s	remaining: 762ms
# 915:	learn: 0.0592578	total: 8.22s	remaining: 753ms
# 916:	learn: 0.0592561	total: 8.22s	remaining: 744ms
# 917:	learn: 0.0592207	total: 8.23s	remaining: 735ms
# 918:	learn: 0.0591940	total: 8.24s	remaining: 726ms
# 919:	learn: 0.0591560	total: 8.25s	remaining: 717ms
# 920:	learn: 0.0591336	total: 8.26s	remaining: 708ms
# 921:	learn: 0.0591152	total: 8.27s	remaining: 699ms
# 922:	learn: 0.0590871	total: 8.27s	remaining: 690ms
# 923:	learn: 0.0590668	total: 8.28s	remaining: 681ms
# 924:	learn: 0.0590304	total: 8.29s	remaining: 672ms
# 925:	learn: 0.0589974	total: 8.3s	remaining: 663ms
# 926:	learn: 0.0589768	total: 8.3s	remaining: 654ms
# 927:	learn: 0.0589424	total: 8.31s	remaining: 645ms
# 928:	learn: 0.0589290	total: 8.32s	remaining: 636ms
# 929:	learn: 0.0589177	total: 8.33s	remaining: 627ms
# 930:	learn: 0.0588949	total: 8.34s	remaining: 618ms
# 931:	learn: 0.0588742	total: 8.35s	remaining: 609ms
# 932:	learn: 0.0588143	total: 8.35s	remaining: 600ms
# 933:	learn: 0.0587775	total: 8.36s	remaining: 591ms
# 934:	learn: 0.0587657	total: 8.37s	remaining: 582ms
# 935:	learn: 0.0587450	total: 8.38s	remaining: 573ms
# 936:	learn: 0.0587271	total: 8.39s	remaining: 564ms
# 937:	learn: 0.0586977	total: 8.39s	remaining: 555ms
# 938:	learn: 0.0586914	total: 8.4s	remaining: 546ms
# 939:	learn: 0.0586634	total: 8.41s	remaining: 537ms
# 940:	learn: 0.0586388	total: 8.42s	remaining: 528ms
# 941:	learn: 0.0586170	total: 8.43s	remaining: 519ms
# 942:	learn: 0.0586101	total: 8.44s	remaining: 510ms
# 943:	learn: 0.0585950	total: 8.45s	remaining: 501ms
# 944:	learn: 0.0585927	total: 8.45s	remaining: 492ms
# 945:	learn: 0.0585796	total: 8.46s	remaining: 483ms
# 946:	learn: 0.0585477	total: 8.47s	remaining: 474ms
# 947:	learn: 0.0585356	total: 8.48s	remaining: 465ms
# 948:	learn: 0.0585182	total: 8.49s	remaining: 456ms
# 949:	learn: 0.0584678	total: 8.49s	remaining: 447ms
# 950:	learn: 0.0584489	total: 8.5s	remaining: 438ms
# 951:	learn: 0.0584340	total: 8.51s	remaining: 429ms
# 952:	learn: 0.0584186	total: 8.52s	remaining: 420ms
# 953:	learn: 0.0583930	total: 8.53s	remaining: 411ms
# 954:	learn: 0.0583626	total: 8.54s	remaining: 402ms
# 955:	learn: 0.0583429	total: 8.54s	remaining: 393ms
# 956:	learn: 0.0583225	total: 8.55s	remaining: 384ms
# 957:	learn: 0.0582955	total: 8.56s	remaining: 375ms
# 958:	learn: 0.0582734	total: 8.57s	remaining: 366ms
# 959:	learn: 0.0582645	total: 8.58s	remaining: 358ms
# 960:	learn: 0.0582581	total: 8.59s	remaining: 349ms
# 961:	learn: 0.0582467	total: 8.6s	remaining: 340ms
# 962:	learn: 0.0582206	total: 8.61s	remaining: 331ms
# 963:	learn: 0.0582031	total: 8.62s	remaining: 322ms
# 964:	learn: 0.0581714	total: 8.63s	remaining: 313ms
# 965:	learn: 0.0581501	total: 8.64s	remaining: 304ms
# 966:	learn: 0.0581261	total: 8.65s	remaining: 295ms
# 967:	learn: 0.0580959	total: 8.66s	remaining: 286ms
# 968:	learn: 0.0580611	total: 8.67s	remaining: 277ms
# 969:	learn: 0.0580390	total: 8.67s	remaining: 268ms
# 970:	learn: 0.0580242	total: 8.69s	remaining: 259ms
# 971:	learn: 0.0579858	total: 8.69s	remaining: 250ms
# 972:	learn: 0.0579701	total: 8.7s	remaining: 241ms
# 973:	learn: 0.0579389	total: 8.71s	remaining: 233ms
# 974:	learn: 0.0578729	total: 8.72s	remaining: 224ms
# 975:	learn: 0.0578442	total: 8.73s	remaining: 215ms
# 976:	learn: 0.0578203	total: 8.74s	remaining: 206ms
# 977:	learn: 0.0578186	total: 8.75s	remaining: 197ms
# 978:	learn: 0.0577990	total: 8.76s	remaining: 188ms
# 979:	learn: 0.0577769	total: 8.77s	remaining: 179ms
# 980:	learn: 0.0577534	total: 8.78s	remaining: 170ms
# 981:	learn: 0.0577211	total: 8.79s	remaining: 161ms
# 982:	learn: 0.0577075	total: 8.79s	remaining: 152ms
# 983:	learn: 0.0576919	total: 8.8s	remaining: 143ms
# 984:	learn: 0.0576694	total: 8.81s	remaining: 134ms
# 985:	learn: 0.0576572	total: 8.82s	remaining: 125ms
# 986:	learn: 0.0576344	total: 8.83s	remaining: 116ms
# 987:	learn: 0.0576051	total: 8.84s	remaining: 107ms
# 988:	learn: 0.0575898	total: 8.85s	remaining: 98.5ms
# 989:	learn: 0.0575816	total: 8.86s	remaining: 89.5ms
# 990:	learn: 0.0575727	total: 8.87s	remaining: 80.6ms
# 991:	learn: 0.0575660	total: 8.88s	remaining: 71.6ms
# 992:	learn: 0.0575488	total: 8.89s	remaining: 62.7ms
# 993:	learn: 0.0575447	total: 8.9s	remaining: 53.7ms
# 994:	learn: 0.0575398	total: 8.91s	remaining: 44.8ms
# 995:	learn: 0.0575253	total: 8.91s	remaining: 35.8ms
# 996:	learn: 0.0575023	total: 8.92s	remaining: 26.9ms
# 997:	learn: 0.0574980	total: 8.93s	remaining: 17.9ms
# 998:	learn: 0.0574763	total: 8.94s	remaining: 8.95ms
# 999:	learn: 0.0574650	total: 8.95s	remaining: 0us
# 0.9604136550650506

# %%
# Задание 6.12

from catboost import Pool
from catboost.utils import get_confusion_matrix

cm = get_confusion_matrix(model, Pool(X_train, y_train))

# %%
cm
# Out:
# array([[46647.,   559.],
#        [ 1273., 34644.]])

# %%
# Задание 6.13

pd.DataFrame(
    {
        "feature_importance": model.get_feature_importance(),
        "feature_names": df.drop(columns="satisfaction").columns,
    }
).sort_values(by=["feature_importance"], ascending=False)
# Out:
#     feature_importance                      feature_names
# 6            26.001691              Inflight wifi service
# 4            17.854438                     Type of Travel
# 11            7.582693                    Online boarding
# 2             7.291082                      Customer Type
# 22            5.334009                     Class_Business
# 17            3.935882                    Checkin service
# 16            3.675108                   Baggage handling
# 3             3.653960                                Age
# 9             3.537978                      Gate location
# 18            2.840194                   Inflight service
# 12            2.804871                       Seat comfort
# 13            2.804743             Inflight entertainment
# 0             1.998636                                 id
# 5             1.688033                    Flight Distance
# 19            1.514438                        Cleanliness
# 8             1.458928             Ease of Online booking
# 14            1.443881                   On-board service
# 7             1.430287  Departure/Arrival time convenient
# 15            1.157490                   Leg room service
# 21            0.846765           Arrival Delay in Minutes
# 20            0.445596         Departure Delay in Minutes
# 10            0.356811                     Food and drink
# 24            0.167712                     Class_Eco Plus
# 23            0.124950                          Class_Eco
# 1             0.049823                             Gender

# %% [markdown]
# # <center>Стекинг</center>

# %% [markdown]
# **Стекинг** —  это агрегация ответов моделей машинного обучения. Подход использует понятие **базовых моделей**, каждая из которых обучается независимо от остальных, и **метамодели**, которая использует предсказания базовых моделей как признаки.
#
# > Важно отметить, что **базовые алгоритмы и метамодель должны обучаться на разных выборках**, чтобы избежать переобучения.
#
# Это можно делать с помощью **блендинга** или **стекинга**.

# %% [markdown]
# **Блендинг** является простейшей реализацией стекинга.
#
# Предположим, у нас есть обучающая выборка $X$, которую мы делим пополам: первая часть используется для обучения базовых моделей, а на второй базовые модели делают предсказания — метапризнаки, на которых и обучается в дальнейшем метамодель.

# %% [markdown]
# ![image.png](https://lms-cdn.skillfactory.ru/assets/courseware/v1/2d3283bba09d12ce993a7984cb111036/asset-v1:Skillfactory+DSMED+2023+type@asset+block/MATHML_md9_7_2.png)

# %% [markdown]
# К сожалению, у блендинга есть проблема: ни базовые модели, ни метамодель не обучаются на полных данных.
#
# Эту проблему решает **стекинг**.
#
# Чтобы в итоге все модели могли «познакомиться» с полным набором данных, можно использовать подход, аналогичный кросс-валидации: мы можем разделять выборку на $L$ частей, обучать модель на части $L-1$ и делать предсказание на оставшейся. Определённого правила для выбора количества частей нет, но, разумеется, чем больше их будет, тем выше будет качество (времени на обучение также будет потрачено больше).

# %% [markdown]
# ![image.png](https://lms-cdn.skillfactory.ru/assets/courseware/v1/fa4292a928728baaf9f760df93701a99/asset-v1:Skillfactory+DSMED+2023+type@asset+block/MATHML_md9_7_3.png)

# %% [markdown]
# Также метод стекинга можно реализовать с более чем двумя уровнями — это называется **многоуровневым стекингом**.

# %%
df = pd.read_csv('data/Frogs_MFCCs.csv')
df.head()
# Out:
#    MFCCs_ 1  MFCCs_ 2  MFCCs_ 3  MFCCs_ 4  MFCCs_ 5  MFCCs_ 6  MFCCs_ 7  \
# 0       1.0  0.152936 -0.105586  0.200722  0.317201  0.260764  0.100945
# 1       1.0  0.171534 -0.098975  0.268425  0.338672  0.268353  0.060835
# 2       1.0  0.152317 -0.082973  0.287128  0.276014  0.189867  0.008714
# 3       1.0  0.224392  0.118985  0.329432  0.372088  0.361005  0.015501
# 4       1.0  0.087817 -0.068345  0.306967  0.330923  0.249144  0.006884
#
#    MFCCs_ 8  MFCCs_ 9  MFCCs_10  ...  MFCCs_17  MFCCs_18  MFCCs_19  MFCCs_20  \
# 0 -0.150063 -0.171128  0.124676  ... -0.108351 -0.077623 -0.009568  0.057684
# 1 -0.222475 -0.207693  0.170883  ... -0.090974 -0.056510 -0.035303  0.020140
# 2 -0.242234 -0.219153  0.232538  ... -0.050691 -0.023590 -0.066722 -0.025083
# 3 -0.194347 -0.098181  0.270375  ... -0.136009 -0.177037 -0.130498 -0.054766
# 4 -0.265423 -0.172700  0.266434  ... -0.048885 -0.053074 -0.088550 -0.031346
#
#    MFCCs_21  MFCCs_22           Family      Genus         Species  RecordID
# 0  0.118680  0.014038  Leptodactylidae  Adenomera  AdenomeraAndre         1
# 1  0.082263  0.029056  Leptodactylidae  Adenomera  AdenomeraAndre         1
# 2  0.099108  0.077162  Leptodactylidae  Adenomera  AdenomeraAndre         1
# 3 -0.018691  0.023954  Leptodactylidae  Adenomera  AdenomeraAndre         1
# 4  0.108610  0.079244  Leptodactylidae  Adenomera  AdenomeraAndre         1
#
# [5 rows x 26 columns]

# %%
df['Family'].value_counts()
# Out:
# Family
# Leptodactylidae    4420
# Hylidae            2165
# Dendrobatidae       542
# Bufonidae            68
# Name: count, dtype: int64

# %%
df['Family'] = df['Family'].map({'Dendrobatidae':1, 'Leptodactylidae':0, 'Hylidae':0, 'Bufonidae':0})

# %%
df['Family'].value_counts()
# Out:
# Family
# 0    6653
# 1     542
# Name: count, dtype: int64

# %%
df_final = df.drop(columns=['Genus', 'Species', 'RecordID'])

# %%
df_final
# Out:
#       MFCCs_ 1  MFCCs_ 2  MFCCs_ 3  MFCCs_ 4  MFCCs_ 5  MFCCs_ 6  MFCCs_ 7  \
# 0          1.0  0.152936 -0.105586  0.200722  0.317201  0.260764  0.100945
# 1          1.0  0.171534 -0.098975  0.268425  0.338672  0.268353  0.060835
# 2          1.0  0.152317 -0.082973  0.287128  0.276014  0.189867  0.008714
# 3          1.0  0.224392  0.118985  0.329432  0.372088  0.361005  0.015501
# 4          1.0  0.087817 -0.068345  0.306967  0.330923  0.249144  0.006884
# ...        ...       ...       ...       ...       ...       ...       ...
# 7190       1.0 -0.554504 -0.337717  0.035533  0.034511  0.443451  0.093889
# 7191       1.0 -0.517273 -0.370574  0.030673  0.068097  0.402890  0.096628
# 7192       1.0 -0.582557 -0.343237  0.029468  0.064179  0.385596  0.114905
# 7193       1.0 -0.519497 -0.307553 -0.004922  0.072865  0.377131  0.086866
# 7194       1.0 -0.508833 -0.324106  0.062068  0.078211  0.397188  0.094596
#
#       MFCCs_ 8  MFCCs_ 9  MFCCs_10  ...  MFCCs_14  MFCCs_15  MFCCs_16  \
# 0    -0.150063 -0.171128  0.124676  ...  0.082245  0.135752 -0.024017
# 1    -0.222475 -0.207693  0.170883  ...  0.022786  0.163320  0.012022
# 2    -0.242234 -0.219153  0.232538  ...  0.050791  0.207338  0.083536
# 3    -0.194347 -0.098181  0.270375  ... -0.011567  0.100413 -0.050224
# 4    -0.265423 -0.172700  0.266434  ...  0.037439  0.219153  0.062837
# ...        ...       ...       ...  ...       ...       ...       ...
# 7190 -0.100753  0.037087  0.081075  ... -0.059364  0.024206 -0.000861
# 7191 -0.116460  0.063727  0.089034  ... -0.105600  0.030767  0.006457
# 7192 -0.103317  0.070370  0.081317  ... -0.078615  0.024861  0.008696
# 7193 -0.115799  0.056979  0.089316  ... -0.075320  0.022903  0.001924
# 7194 -0.117672  0.058874  0.076180  ... -0.073415  0.042517  0.004158
#
#       MFCCs_17  MFCCs_18  MFCCs_19  MFCCs_20  MFCCs_21  MFCCs_22  Family
# 0    -0.108351 -0.077623 -0.009568  0.057684  0.118680  0.014038       0
# 1    -0.090974 -0.056510 -0.035303  0.020140  0.082263  0.029056       0
# 2    -0.050691 -0.023590 -0.066722 -0.025083  0.099108  0.077162       0
# 3    -0.136009 -0.177037 -0.130498 -0.054766 -0.018691  0.023954       0
# 4    -0.048885 -0.053074 -0.088550 -0.031346  0.108610  0.079244       0
# ...        ...       ...       ...       ...       ...       ...     ...
# 7190  0.069430  0.071001  0.021591  0.052449 -0.021860 -0.079860       0
# 7191  0.061127  0.068978  0.017745  0.046461 -0.015418 -0.101892       0
# 7192  0.082474  0.077771 -0.009688  0.027834 -0.000531 -0.080425       0
# 7193  0.051796  0.069073  0.017963  0.041803 -0.027911 -0.096895       0
# 7194  0.061455  0.072983 -0.003980  0.031560 -0.029355 -0.087910       0
#
# [7195 rows x 23 columns]

# %%
X = df_final.drop('Family', axis = 1)
y = df_final['Family']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=31)

# %%
# Задание 7.5

model_rfc = RandomForestClassifier(10, random_state=42)
model_rfc.fit(X_train, y_train)
pred = model_rfc.predict(X_test)
f1_score(y_test, pred)
# Out:
# 0.9726775956284153

# %%
# Задание 7.6

from sklearn.neighbors import KNeighborsClassifier 
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import StackingClassifier

estimators = [('rf', RandomForestClassifier(n_estimators=10, random_state=31)),
              ('knn', KNeighborsClassifier(n_neighbors= 11)),
              ('nb', GaussianNB() )               
]
metamodel = StackingClassifier(
    estimators=estimators, final_estimator=LogisticRegression()
)
metamodel.fit(X_train, y_train)
pred = metamodel.predict(X_test)
f1_score(y_test, pred)
# Out:
# 0.989247311827957

# %% [markdown]
# ![image.png](https://lms-cdn.skillfactory.ru/assets/courseware/v1/e62f9c293fb2c6ffd7e438197bf03e90/asset-v1:Skillfactory+DSMED+2023+type@asset+block/MATHML_md9_8_1.png)
#
# ![image.png](https://lms-cdn.skillfactory.ru/assets/courseware/v1/51c72308fa8d6dad07bd9a5f09a83ab6/asset-v1:Skillfactory+DSMED+2023+type@asset+block/MATHML_md9_8_2.png)
#
# ![image.png](https://lms-cdn.skillfactory.ru/assets/courseware/v1/7c28d960b938cd73e5908b9746548738/asset-v1:Skillfactory+DSMED+2023+type@asset+block/MATHML_md9_8_3.png)

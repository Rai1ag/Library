# %%
import pandas as pd
df = pd.read_csv('data/Dataset_heart.csv')
df.head()
# Out:
#    Unnamed: 0  age  sex  chest pain type  resting bps  cholesterol  \
# 0           0   40    1                2          140        289.0
# 1           1   49    0                3          160        180.0
# 2           2   37    1                2          130        283.0
# 3           3   48    0                4          138        214.0
# 4           4   54    1                3          150        195.0
#
#    fasting blood sugar  resting ecg  max heart rate  exercise angina  oldpeak  \
# 0                    0            0             172                0      0.0
# 1                    0            0             156                0      1.0
# 2                    0            1              98                0      0.0
# 3                    0            0             108                1      1.5
# 4                    0            0             122                0      0.0
#
#    ST slope  target
# 0         1       0
# 1         2       1
# 2         1       0
# 3         2       1
# 4         1       0

# %% [markdown]
# # Описание колонок:
# (в точности как это было дано в условии к заданию)
#
# 1) **id** - уникальный идентификатор для каждого пациента;
#
# 2) **age** - возраст пациента в годах;
#
# 3) **origin** - место учебы;
#
# 4) **sex** - пол:
# * мужской
# * женский
#
# 5) **cp (chest pain type)** - тип стенокардии:
# * типичная стенокардия
# * атипичная стенокардия
# * неангинальная
# * бессимптомная
#
# 6) **trestbps (resting blood pressure)** - кровяное давление покоя (в мм рт.ст. при поступлении в стационар);
#
# 7) **chol** - холестерин сыворотки (в мг/дл);
#
# 8) **fbs** - если уровень сахара в крови натощак > 120 мг/дл;
#
# 9) **restecg** - результаты электрокардиографии в состоянии покоя:
# * normal (норма)
# * stt abnormality (отклонения от нормы)
# * lv hypertrophy (гипертрофия ЛЖ)
#
# 10) **thalach** - достигается максимальная частота сердечных сокращений;
#
# 11) **exang** - стенокардия, вызванная физической нагрузкой:
# * True
# * False
#
# 12) **oldpeak** - депрессия ST, вызванная нагрузкой по сравнению с отдыхом;
#
# 13) **slope** - наклон пикового сегмента ST при нагрузке;
#
# 14) **ca** - количество крупных сосудов (0–3), окрашенных при рентгеноскопии;
#
# 15) **thal**:
# * normal (нормальный)
# * fixed defect (исправленный дефект)
# * reversible defect (обратимый дефект)
#
# 16) **num** - прогнозируемый атрибут.

# %% [markdown]
# # <center>Теоретическое резюме</center>

# %% [markdown]
# **Решаемые задачи:**
#
# * отображение X в Y: текст, изображения, видео, звук, низкоразмерные данные
#
# **Типы архитектур:**
#
# * Для распознавания и синтеза визуальных данных → **свёрточные сети (CNN)**
# * Для распознавания и синтеза последовательностей → **рекуррентные сети (RNN)**
# * Для улучшения качества синтеза → **состязательные сети (GAN)**
#
# **Факторы успеха:**
#
# * топология, данные, железо (GPU)
